# %%
from google.colab import drive
import os

# 1. Mount Drive
drive.mount('/content/drive')

# 2. Clone NHÁNH convnext-v2-dev
if not os.path.exists('/content/FR_Photometric_Stereo'):
    # !git clone -b convnext-v2-dev https://github.com/minh4923/FR_Photometric_Stereo.git

# 3. Di chuyển vào thư mục dự án
# %cd /content/FR_Photometric_Stereo

# 4. Cài đặt thư viện
# !pip install -q albumentations==1.3.1 timm
# Out:
# Mounted at /content/drive
# Cloning into 'FR_Photometric_Stereo'...
# remote: Enumerating objects: 142, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 142 (delta 48), reused 132 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (142/142), 10.79 MiB | 32.80 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/FR_Photometric_Stereo
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.7/125.7 kB 7.7 MB/s eta 0:00:00

# %%
# %cd /content/FR_Photometric_Stereo
import warnings
warnings.filterwarnings("ignore")
import torch
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
import albumentations as A
import os
import pandas as pd

# Import các module đã sửa đổi
from going_modular.dataloader.multitask import create_multitask_datafetcher
from going_modular.model.MTLFaceRecognition import MTLFaceRecognition
from going_modular.loss.MultiTaskLoss import MultiTaskLoss
from going_modular.train_eval.train import fit
from going_modular.utils.transforms import RandomResizedCropRect, GaussianNoise
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint
from going_modular.utils.ExperimentManager import ExperimentManager

# --- CẤU HÌNH ---
device = "cuda" if torch.cuda.is_available() else "cpu"
seed = 42
torch.manual_seed(seed)

# 1. ĐẶT TÊN THÍ NGHIỆM (ConvNeXt + PK Sampler)
EXPERIMENT_NAME = "Single_NORMALMAP_PK_SAMPLER_ConvNextV2"

CONFIGURATION = {
    'note': EXPERIMENT_NAME,
    'dataset_dir': '/content/drive/MyDrive/Photometric_DB_Full/',

    # --- CHỌN LOẠI DỮ LIỆU ---
    'type': 'normalmap',

    # --- CẤU HÌNH QUAN TRỌNG ---
    'backbone': 'convnextv2_tiny', # Đã đổi sang ConvNeXt
    'use_sampler': True,           # Kích hoạt PK Sampler (Mỗi batch chọn K người, P ảnh)

    'device': device,
    'epochs': 100,
    'batch_size': 16, # Giảm xuống 16 để tránh lỗi OOM với ConvNeXt
    'image_size': 112,
    'base_lr': 1e-4,
    'num_classes': None, # Sẽ tự tính bên dưới

    # Trọng số loss
    'loss_gender_weight': 1.0,      'loss_da_gender_weight': 0.1,
    'loss_emotion_weight': 0.5,     'loss_da_emotion_weight': 0.1,
    'loss_pose_weight': 1.0,        'loss_da_pose_weight': 0.1,
    'loss_spectacles_weight': 0.5,  'loss_da_spectacles_weight': 0.1,
    'loss_facial_hair_weight': 0.5, 'loss_da_facial_hair_weight': 0.1,
}

# --- 1. KHỞI TẠO MANAGER ---
manager = ExperimentManager(CONFIGURATION)
manager.log_text(f"TRAINING MODE: {CONFIGURATION['type']} | Backbone: {CONFIGURATION['backbone']} | PK Sampler: {CONFIGURATION['use_sampler']}")

# --- 2. DATASET ---
train_csv_path = os.path.join(CONFIGURATION['dataset_dir'], 'dataset/train_split.csv')
if not os.path.exists(train_csv_path): train_csv_path = os.path.join(CONFIGURATION['dataset_dir'], 'train_split.csv')

# Load CSV để lấy num_classes chính xác (Khớp với logic 2232)
df_temp = pd.read_csv(train_csv_path)
CONFIGURATION['num_classes'] = df_temp['id'].max() + 1
manager.log_text(f"Max ID in CSV: {df_temp['id'].max()} -> Set num_classes: {CONFIGURATION['num_classes']}")

train_transform = A.Compose([
    RandomResizedCropRect(CONFIGURATION['image_size']),
    GaussianNoise(p=0.2),
    A.HorizontalFlip(p=0.5)
], additional_targets={'albedo': 'image', 'depthmap': 'image', 'normal': 'image'})

test_transform = A.Compose([
    A.Resize(CONFIGURATION['image_size'], CONFIGURATION['image_size'])
], additional_targets={'albedo': 'image', 'depthmap': 'image', 'normal': 'image'})

# Load Dataloader (multitask.py sẽ tự xử lý PK Sampler nếu use_sampler=True)
train_dl, test_dl, _ = create_multitask_datafetcher(CONFIGURATION, train_transform, test_transform)

# --- 3. MODEL & LOSS ---
# Model sẽ tự động chọn ConvNeXt nhờ class MTLFaceRecognition đã sửa
model = MTLFaceRecognition(CONFIGURATION['backbone'], CONFIGURATION['num_classes'])

criterion = MultiTaskLoss(train_csv_path, CONFIGURATION)
optimizer = Adam(model.parameters(), lr=CONFIGURATION['base_lr'])
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=20, T_mult=2)

# --- 4. CHECKPOINT SAVER ---
ckpt_saver = ModelCheckpoint(
    output_dir=manager.ckpt_dir,
    mode='max',
    best_metric_name='auc_id_cosine'
)

early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['cosine_auc'], patience=1500, mode='max', verbose=0,
    save_dir=manager.ckpt_dir, start_from_epoch=0
)

# --- 5. RUN ---
print(f" Bắt đầu train Single Task: {CONFIGURATION['type'].upper()} với ConvNeXt V2...")
fit(
    conf=CONFIGURATION,
    start_epoch=0,
    model=model,
    train_dataloader=train_dl,
    test_dataloader=test_dl,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    early_stopping=early_stopping,
    model_checkpoint=ckpt_saver,
    existing_manager=manager
)
# Out:
# /content/FR_Photometric_Stereo
# KHOI TAO THI NGHIEM: Single_NORMALMAP_PK_SAMPLER_ConvNextV2
# Luu tru tai: /content/drive/MyDrive/Photometric_DB_Full/experiments/Single_NORMALMAP_PK_SAMPLER_ConvNextV2
# Thoi gian: 2026-01-11 09:58:18
# --------------------------------------------------
# TRAINING MODE: normalmap | Backbone: convnextv2_tiny | PK Sampler: True
# Max ID in CSV: 2231 -> Set num_classes: 2232
# >>> SingleLoader: MODE = PK SAMPLER
# --- Loading ConvNeXt V2: convnextv2_tiny (Pretrained=True) ---
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
#  Bắt đầu train Single Task: NORMALMAP với ConvNeXt V2...
# BAT DAU TRAINING: Single_NORMALMAP_PK_SAMPLER_ConvNextV2
#
# --- Epoch 1/100 ---
# Ep 1:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 17.7491   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 28.7103   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.64902  │ 0.5730311605665419  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.685471 │ 0.8195533686214023  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.679849 │ 0.6866221692827013  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.688924 │ 0.6929311454296112  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.687115 │ 0.6728894445631239  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.686496 │ 0.6813148856163025  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.66553  │ 0.6628645757834116  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.67381  │ 0.6983500652843051  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.686094 │ 0.6496790018346574  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.685606 │ 0.7069486147827573  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.680755 │ 0.7213469261662033  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.531854 │ 0.4947192513368984  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.535889 │ 0.47881773399014776 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.59846  │ 0.5121342177136168  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.50574  │ 0.5628191489361702  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.760237 │ 0.7209831781010899  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.760237 │ 0.7209844610255302  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 1: loss: 17.7491, loss_id: 28.7103, loss_gender: 0.5730, loss_da_gender: 0.8196, loss_emotion: 0.6866, loss_da_emotion: 0.6929, loss_pose: 0.6729, loss_da_pose: 0.6813, loss_facial_hair: 0.6629, loss_da_facial_hair: 0.6984, loss_spectacles: 0.6497, loss_da_spectacles: 0.7069, auc_gender: 0.7213, auc_spectacles: 0.4947, auc_facial_hair: 0.4788, auc_pose: 0.5121, auc_emotion: 0.5628, auc_id_cosine: 0.7210, auc_id_euclidean: 0.7210
# --> SAVE BEST MODEL (auc_id_cosine: 0.7210)
#
# --- Epoch 2/100 ---
# Ep 2:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 19.7248   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 32.954    │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.581019 │ 0.7749321593178643  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.63005  │ 0.5258738415108787  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.665133 │ 0.6868693000740476  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.67292  │ 0.6905600825945536  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.64796  │ 0.8920299179024167  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.650221 │ 0.6789501872327592  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.63819  │ 0.7106537057293786  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.642234 │ 0.6564656959639655  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.68409  │ 0.7079153623845842  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.683711 │ 0.7353562315305074  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.730276 │ 0.7317475028318403  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.508971 │ 0.4530748663101605  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.539204 │ 0.45470878006374965 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.498189 │ 0.5342957471712837  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.635671 │ 0.5957446808510638  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.872663 │ 0.7522538803865155  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.872663 │ 0.7522548728374978  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 2: loss: 19.7248, loss_id: 32.9540, loss_gender: 0.7749, loss_da_gender: 0.5259, loss_emotion: 0.6869, loss_da_emotion: 0.6906, loss_pose: 0.8920, loss_da_pose: 0.6790, loss_facial_hair: 0.7107, loss_da_facial_hair: 0.6565, loss_spectacles: 0.7079, loss_da_spectacles: 0.7354, auc_gender: 0.7317, auc_spectacles: 0.4531, auc_facial_hair: 0.4547, auc_pose: 0.5343, auc_emotion: 0.5957, auc_id_cosine: 0.7523, auc_id_euclidean: 0.7523
# --> SAVE BEST MODEL (auc_id_cosine: 0.7523)
#
# --- Epoch 3/100 ---
# Ep 3:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 20.112    │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.9849   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.518871 │ 0.5705296215083864  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.573225 │ 0.5077160381608539  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.652467 │ 1.429386105802324   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.662885 │ 0.7610169914033678  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.622014 │ 0.8049791985087924  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.626653 │ 0.7271884845362769  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.612513 │ 0.7038668990135193  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.615206 │ 0.6598368800348706  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.677144 │ 0.6446106864346398  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.678091 │ 0.652454149391916   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.623079 │ 0.6161054474307487  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.53163  │ 0.3655080213903743  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.51613  │ 0.5003767024050999  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.502913 │ 0.46086617245415534 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.579645 │ 0.6024468085106384  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.850941 │ 0.7470305140431329  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.850941 │ 0.7470307803104697  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 3: loss: 20.1120, loss_id: 33.9849, loss_gender: 0.5705, loss_da_gender: 0.5077, loss_emotion: 1.4294, loss_da_emotion: 0.7610, loss_pose: 0.8050, loss_da_pose: 0.7272, loss_facial_hair: 0.7039, loss_da_facial_hair: 0.6598, loss_spectacles: 0.6446, loss_da_spectacles: 0.6525, auc_gender: 0.6161, auc_spectacles: 0.3655, auc_facial_hair: 0.5004, auc_pose: 0.4609, auc_emotion: 0.6024, auc_id_cosine: 0.7470, auc_id_euclidean: 0.7470
#
# --- Epoch 4/100 ---
# Ep 4:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 20.0366   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.9969   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.475895 │ 0.6095020688242383  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.527798 │ 0.5245582179890739  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.649055 │ 1.3871608475844066  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.65628  │ 0.8159743249416351  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.610226 │ 0.7075102693504758  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.614199 │ 0.7039110461870829  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.592191 │ 0.672071185376909   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.593951 │ 0.665349930524826   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.678249 │ 0.6427729907963011  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.678373 │ 0.6543466614352332  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.667638 │ 0.6350530326433941  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.519646 │ 0.38395721925133686 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.568109 │ 0.47360185453491743 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.545804 │ 0.4994927818962153  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.585972 │ 0.6016489361702128  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.836338 │ 0.7388550175320097  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.836338 │ 0.738855308005468   │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 4: loss: 20.0366, loss_id: 33.9969, loss_gender: 0.6095, loss_da_gender: 0.5246, loss_emotion: 1.3872, loss_da_emotion: 0.8160, loss_pose: 0.7075, loss_da_pose: 0.7039, loss_facial_hair: 0.6721, loss_da_facial_hair: 0.6653, loss_spectacles: 0.6428, loss_da_spectacles: 0.6543, auc_gender: 0.6351, auc_spectacles: 0.3840, auc_facial_hair: 0.4736, auc_pose: 0.4995, auc_emotion: 0.6016, auc_id_cosine: 0.7389, auc_id_euclidean: 0.7389
#
# --- Epoch 5/100 ---
# Ep 5:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 19.9899   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.9024   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.48517  │ 1.9329517086346943  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.517523 │ 1.4242223368750677  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.637431 │ 0.743379447195265   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.646397 │ 0.7341196040312449  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.618558 │ 0.7073520322640737  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.62102  │ 0.7006245685948266  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.59575  │ 0.8144287351104949  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.597062 │ 0.6826439284616046  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.679115 │ 0.730859657128652   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.679393 │ 0.7568086650636461  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.767868 │ 0.7892081145093194  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.542312 │ 0.39779411764705885 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.580152 │ 0.467864387134164   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.520962 │ 0.5113538821693329  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.534447 │ 0.5936170212765958  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.855842 │ 0.7536310150517538  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.855842 │ 0.7536310150517537  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 5: loss: 19.9899, loss_id: 33.9024, loss_gender: 1.9330, loss_da_gender: 1.4242, loss_emotion: 0.7434, loss_da_emotion: 0.7341, loss_pose: 0.7074, loss_da_pose: 0.7006, loss_facial_hair: 0.8144, loss_da_facial_hair: 0.6826, loss_spectacles: 0.7309, loss_da_spectacles: 0.7568, auc_gender: 0.7892, auc_spectacles: 0.3978, auc_facial_hair: 0.4679, auc_pose: 0.5114, auc_emotion: 0.5936, auc_id_cosine: 0.7536, auc_id_euclidean: 0.7536
# --> SAVE BEST MODEL (auc_id_cosine: 0.7536)
#
# --- Epoch 6/100 ---
# Ep 6:
# ╒═════════════════════╤═══════════╤════════════════════╕
# │ Metric              │     Train │ Test               │
# ╞═════════════════════╪═══════════╪════════════════════╡
# │ loss                │ 20.0066   │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_id             │ 34.0163   │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_gender         │  0.443143 │ 3.1684725946850247 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_gender      │  0.465919 │ 0.6881818175315857 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_emotion        │  0.646991 │ 2.744686702887217  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_emotion     │  0.648448 │ 0.712799416648017  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_pose           │  0.632196 │ 0.6678243213229709 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_pose        │  0.635227 │ 0.6874817195865843 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_facial_hair    │  0.588287 │ 0.8989172366758188 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_facial_hair │  0.589569 │ 1.2650087900045845 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_spectacles     │  0.672497 │ 0.6691915608114667 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_spectacles  │  0.674489 │ 0.6462445788913302 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_gender          │  0.705895 │ 0.7660385130264648 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_spectacles      │  0.542732 │ 0.4124331550802139 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_facial_hair     │  0.556759 │ 0.4742973051289481 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_pose            │  0.417741 │ 0.4925477955520874 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_emotion         │  0.626303 │ 0.6119148936170213 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_cosine       │  0.827912 │ 0.7345943770535264 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_euclidean    │  0.827912 │ 0.734593989755582  │
# ╘═════════════════════╧═══════════╧════════════════════╛
# Ep 6: loss: 20.0066, loss_id: 34.0163, loss_gender: 3.1685, loss_da_gender: 0.6882, loss_emotion: 2.7447, loss_da_emotion: 0.7128, loss_pose: 0.6678, loss_da_pose: 0.6875, loss_facial_hair: 0.8989, loss_da_facial_hair: 1.2650, loss_spectacles: 0.6692, loss_da_spectacles: 0.6462, auc_gender: 0.7660, auc_spectacles: 0.4124, auc_facial_hair: 0.4743, auc_pose: 0.4925, auc_emotion: 0.6119, auc_id_cosine: 0.7346, auc_id_euclidean: 0.7346
#
# --- Epoch 7/100 ---
# Ep 7:
# ╒═════════════════════╤═══════════╤════════════════════╕
# │ Metric              │     Train │ Test               │
# ╞═════════════════════╪═══════════╪════════════════════╡
# │ loss                │ 19.9499   │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_id             │ 33.9245   │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_gender         │  0.45667  │ 2.190184017022451  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_gender      │  0.473592 │ 1.3107964396476746 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_emotion        │  0.641634 │ 0.7506432566377852 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_emotion     │  0.643225 │ 0.7750227418210771 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_pose           │  0.615286 │ 0.6672153373559316 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_pose        │  0.615741 │ 0.7029695742660098 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_facial_hair    │  0.592996 │ 0.7831006985571649 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_facial_hair │  0.594878 │ 0.7806026438872019 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_spectacles     │  0.6702   │ 0.6725341478983561 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_spectacles  │  0.671065 │ 0.655457498298751  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_gender          │  0.709231 │ 0.7674801771187313 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_spectacles      │  0.520901 │ 0.3932486631016042 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_facial_hair     │  0.549979 │ 0.4780643291799479 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_pose            │  0.469651 │ 0.5577838470542333 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_emotion         │  0.600297 │ 0.5818085106382979 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_cosine       │  0.81607  │ 0.7257304342403915 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_euclidean    │  0.81607  │ 0.7257304584465131 │
# ╘═════════════════════╧═══════════╧════════════════════╛
# Ep 7: loss: 19.9499, loss_id: 33.9245, loss_gender: 2.1902, loss_da_gender: 1.3108, loss_emotion: 0.7506, loss_da_emotion: 0.7750, loss_pose: 0.6672, loss_da_pose: 0.7030, loss_facial_hair: 0.7831, loss_da_facial_hair: 0.7806, loss_spectacles: 0.6725, loss_da_spectacles: 0.6555, auc_gender: 0.7675, auc_spectacles: 0.3932, auc_facial_hair: 0.4781, auc_pose: 0.5578, auc_emotion: 0.5818, auc_id_cosine: 0.7257, auc_id_euclidean: 0.7257
#
# --- Epoch 8/100 ---
# Ep 8:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 19.9191   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.8888   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.438356 │ 1.2376325792736478  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.450545 │ 0.7503508097595639  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.631107 │ 1.2268361465798483  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.634591 │ 0.6904751923349168  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.626457 │ 0.6673991117212508  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.627766 │ 0.708639058801863   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.598767 │ 0.7914234979285134  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.60085  │ 0.8003742545843124  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.670186 │ 0.6783120201693641  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.670771 │ 0.6794564144478904  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.741603 │ 0.7812789620018534  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.564316 │ 0.37981283422459894 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.558263 │ 0.4812518110692553  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.480474 │ 0.5435817401482635  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.626909 │ 0.6002127659574469  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.836334 │ 0.7367827798813434  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.836334 │ 0.736782755675222   │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 8: loss: 19.9191, loss_id: 33.8888, loss_gender: 1.2376, loss_da_gender: 0.7504, loss_emotion: 1.2268, loss_da_emotion: 0.6905, loss_pose: 0.6674, loss_da_pose: 0.7086, loss_facial_hair: 0.7914, loss_da_facial_hair: 0.8004, loss_spectacles: 0.6783, loss_da_spectacles: 0.6795, auc_gender: 0.7813, auc_spectacles: 0.3798, auc_facial_hair: 0.4813, auc_pose: 0.5436, auc_emotion: 0.6002, auc_id_cosine: 0.7368, auc_id_euclidean: 0.7368
#
# --- Epoch 9/100 ---
# Ep 9:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 19.907    │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.783    │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.468722 │ 0.5996690897477998  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.486726 │ 0.5502783026960161  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.641489 │ 0.6894481033086777  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.648037 │ 0.6831797146134906  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.630497 │ 0.6810623440477583  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.635099 │ 0.6732008506854376  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.591247 │ 0.7028108868334029  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.592046 │ 0.8013504693905512  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.668412 │ 0.6647405044900047  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.6687   │ 0.670605503850513   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.829479 │ 0.7626403048089796  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.569416 │ 0.39639037433155083 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.584445 │ 0.4884381338742394  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.609805 │ 0.46390948107686303 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.622597 │ 0.6215425531914894  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.870817 │ 0.7961280807857036  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.870817 │ 0.7961280565795822  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 9: loss: 19.9070, loss_id: 33.7830, loss_gender: 0.5997, loss_da_gender: 0.5503, loss_emotion: 0.6894, loss_da_emotion: 0.6832, loss_pose: 0.6811, loss_da_pose: 0.6732, loss_facial_hair: 0.7028, loss_da_facial_hair: 0.8014, loss_spectacles: 0.6647, loss_da_spectacles: 0.6706, auc_gender: 0.7626, auc_spectacles: 0.3964, auc_facial_hair: 0.4884, auc_pose: 0.4639, auc_emotion: 0.6215, auc_id_cosine: 0.7961, auc_id_euclidean: 0.7961
# --> SAVE BEST MODEL (auc_id_cosine: 0.7961)
#
# --- Epoch 10/100 ---
# Ep 10:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 19.9254   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.8666   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.465973 │ 1.1065274344550238  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.47943  │ 1.4062042269441817  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.63665  │ 0.7792726258436838  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.641161 │ 0.7652861211034987  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.624025 │ 0.702338715394338   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.624702 │ 0.7126354873180389  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.585054 │ 0.6569030202097363  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.587713 │ 0.6695999933613671  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.669401 │ 0.8148889574739668  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.670095 │ 0.7627450029055277  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.736435 │ 0.7710843373493975  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.563287 │ 0.37212566844919787 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.575293 │ 0.4925528832222544  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.548641 │ 0.4792040577448303  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.623377 │ 0.5707446808510639  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.853595 │ 0.7488651686111283  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.853595 │ 0.7488656043213154  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 10: loss: 19.9254, loss_id: 33.8666, loss_gender: 1.1065, loss_da_gender: 1.4062, loss_emotion: 0.7793, loss_da_emotion: 0.7653, loss_pose: 0.7023, loss_da_pose: 0.7126, loss_facial_hair: 0.6569, loss_da_facial_hair: 0.6696, loss_spectacles: 0.8149, loss_da_spectacles: 0.7627, auc_gender: 0.7711, auc_spectacles: 0.3721, auc_facial_hair: 0.4926, auc_pose: 0.4792, auc_emotion: 0.5707, auc_id_cosine: 0.7489, auc_id_euclidean: 0.7489
#
# --- Epoch 11/100 ---
# Ep 11:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 19.8787   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.8475   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.437858 │ 0.9473521790156761  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.452655 │ 1.0260805018349655  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.631909 │ 1.4233595298396216  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.637439 │ 1.2505975133842893  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.607384 │ 0.6778365340497758  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.608555 │ 0.690502706501219   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.589221 │ 0.6692287342415916  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.589906 │ 0.7313550081517961  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.677308 │ 0.6758312028315332  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.67758  │ 0.7802479275398784  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.619606 │ 0.5555555555555556  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.565006 │ 0.38709893048128347 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.442119 │ 0.5349174152419589  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.547473 │ 0.48505657432696064 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.581527 │ 0.5975531914893617  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.856333 │ 0.7548131694081874  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.856333 │ 0.7548133388510381  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 11: loss: 19.8787, loss_id: 33.8475, loss_gender: 0.9474, loss_da_gender: 1.0261, loss_emotion: 1.4234, loss_da_emotion: 1.2506, loss_pose: 0.6778, loss_da_pose: 0.6905, loss_facial_hair: 0.6692, loss_da_facial_hair: 0.7314, loss_spectacles: 0.6758, loss_da_spectacles: 0.7802, auc_gender: 0.5556, auc_spectacles: 0.3871, auc_facial_hair: 0.5349, auc_pose: 0.4851, auc_emotion: 0.5976, auc_id_cosine: 0.7548, auc_id_euclidean: 0.7548
#
# --- Epoch 12/100 ---
# Ep 12:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 19.9095   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.7954   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.483937 │ 2.970973425441318   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.500187 │ 2.0052478975719876  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.634035 │ 1.0550368908378813  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.637633 │ 0.9077371656894684  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.618344 │ 0.6756183074580299  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.617481 │ 0.6683129337098863  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.593181 │ 0.8621882514821159  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.597031 │ 0.8037475355797343  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.670784 │ 0.7622671756479475  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.670982 │ 0.7395630876223246  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.703452 │ 0.7599629286376274  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.563163 │ 0.3917112299465241  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.570934 │ 0.47887568820631704 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.474513 │ 0.5061256340226297  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.607901 │ 0.543031914893617   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.847166 │ 0.7454014904774086  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.847166 │ 0.7454018777753528  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 12: loss: 19.9095, loss_id: 33.7954, loss_gender: 2.9710, loss_da_gender: 2.0052, loss_emotion: 1.0550, loss_da_emotion: 0.9077, loss_pose: 0.6756, loss_da_pose: 0.6683, loss_facial_hair: 0.8622, loss_da_facial_hair: 0.8037, loss_spectacles: 0.7623, loss_da_spectacles: 0.7396, auc_gender: 0.7600, auc_spectacles: 0.3917, auc_facial_hair: 0.4789, auc_pose: 0.5061, auc_emotion: 0.5430, auc_id_cosine: 0.7454, auc_id_euclidean: 0.7454
#
# --- Epoch 13/100 ---
# Ep 13:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 19.9137   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.8591   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.445163 │ 1.5037240948941972  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.465589 │ 0.8894087043073442  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.633394 │ 0.7477964576747682  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.635955 │ 0.7446666260560354  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.626222 │ 0.6728028986189101  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.628328 │ 0.6719483915302489  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.591134 │ 0.8413609812657038  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.594753 │ 0.7744638141658571  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.673593 │ 0.6468311018413968  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.674155 │ 0.6746801965766482  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.741334 │ 0.7788075378436825  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.572415 │ 0.3927139037433155  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.567156 │ 0.48791654592871636 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.47059  │ 0.5523995317986734  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.620027 │ 0.5656914893617022  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.828205 │ 0.7296490906341093  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.828205 │ 0.7296489938096233  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 13: loss: 19.9137, loss_id: 33.8591, loss_gender: 1.5037, loss_da_gender: 0.8894, loss_emotion: 0.7478, loss_da_emotion: 0.7447, loss_pose: 0.6728, loss_da_pose: 0.6719, loss_facial_hair: 0.8414, loss_da_facial_hair: 0.7745, loss_spectacles: 0.6468, loss_da_spectacles: 0.6747, auc_gender: 0.7788, auc_spectacles: 0.3927, auc_facial_hair: 0.4879, auc_pose: 0.5524, auc_emotion: 0.5657, auc_id_cosine: 0.7296, auc_id_euclidean: 0.7296
#
# --- Epoch 14/100 ---
# Ep 14:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 19.8383   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.7181   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.43486  │ 0.4927397593855858  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.46118  │ 0.562916679514779   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.632219 │ 0.7260975191990534  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.637182 │ 0.7092548525995679  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.625075 │ 0.6987971431679196  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.629339 │ 0.6807443598906199  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.594681 │ 0.6593723628256056  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.598522 │ 0.6597615480422974  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.671862 │ 0.6838948445187675  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.67355  │ 0.6917237506972419  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.663579 │ 0.7041499330655958  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.519951 │ 0.35661764705882354 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.489946 │ 0.5055925818603304  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.546132 │ 0.4876316816230979  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.596074 │ 0.6080319148936171  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.874532 │ 0.7909051017402652  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.874532 │ 0.7909049807096576  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 14: loss: 19.8383, loss_id: 33.7181, loss_gender: 0.4927, loss_da_gender: 0.5629, loss_emotion: 0.7261, loss_da_emotion: 0.7093, loss_pose: 0.6988, loss_da_pose: 0.6807, loss_facial_hair: 0.6594, loss_da_facial_hair: 0.6598, loss_spectacles: 0.6839, loss_da_spectacles: 0.6917, auc_gender: 0.7041, auc_spectacles: 0.3566, auc_facial_hair: 0.5056, auc_pose: 0.4876, auc_emotion: 0.6080, auc_id_cosine: 0.7909, auc_id_euclidean: 0.7909
#
# --- Epoch 15/100 ---
# Ep 15:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 19.8913   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.8037   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.465139 │ 0.4368965453985665  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.480733 │ 0.4458536191119088  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.64051  │ 0.948851035700904   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.644578 │ 0.9399013453059726  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.627287 │ 0.7061789366934035  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.630786 │ 0.6813670032554202  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.573685 │ 0.7346400684780545  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.577882 │ 0.7899127817816205  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.66841  │ 0.6487385034561157  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.669948 │ 0.6615196135309007  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.754436 │ 0.7673772011121409  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.573654 │ 0.3822860962566845  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.552151 │ 0.4823529411764706  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.541589 │ 0.47569254779555215 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.635674 │ 0.6139361702127659  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.878573 │ 0.7563599647791249  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.878573 │ 0.7563600858097326  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 15: loss: 19.8913, loss_id: 33.8037, loss_gender: 0.4369, loss_da_gender: 0.4459, loss_emotion: 0.9489, loss_da_emotion: 0.9399, loss_pose: 0.7062, loss_da_pose: 0.6814, loss_facial_hair: 0.7346, loss_da_facial_hair: 0.7899, loss_spectacles: 0.6487, loss_da_spectacles: 0.6615, auc_gender: 0.7674, auc_spectacles: 0.3823, auc_facial_hair: 0.4824, auc_pose: 0.4757, auc_emotion: 0.6139, auc_id_cosine: 0.7564, auc_id_euclidean: 0.7564
#
# --- Epoch 16/100 ---
# Ep 16:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 19.7959   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.7056   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.430102 │ 1.4745747314559088  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.458922 │ 1.119224362903171   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.622056 │ 0.7544644210073683  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.62883  │ 0.7595481243398454  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.614864 │ 0.6780258946948581  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.616916 │ 0.6769066751003265  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.584235 │ 0.7493570885724492  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.587841 │ 0.7127507734629843  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.670389 │ 0.6916015909777747  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.671977 │ 0.7279955181810591  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.725043 │ 0.762537328802389   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.56961  │ 0.3872994652406418  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.581865 │ 0.4835120254998551  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.536058 │ 0.49309403043308625 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.585718 │ 0.5270744680851064  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.875804 │ 0.7620167659343573  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.875804 │ 0.7620168385527217  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 16: loss: 19.7959, loss_id: 33.7056, loss_gender: 1.4746, loss_da_gender: 1.1192, loss_emotion: 0.7545, loss_da_emotion: 0.7595, loss_pose: 0.6780, loss_da_pose: 0.6769, loss_facial_hair: 0.7494, loss_da_facial_hair: 0.7128, loss_spectacles: 0.6916, loss_da_spectacles: 0.7280, auc_gender: 0.7625, auc_spectacles: 0.3873, auc_facial_hair: 0.4835, auc_pose: 0.4931, auc_emotion: 0.5271, auc_id_cosine: 0.7620, auc_id_euclidean: 0.7620
#
# --- Epoch 17/100 ---
# Ep 17:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 19.8236   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 33.7175   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.446055 │ 0.43528762542539173 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.46765  │ 0.47956737462017274 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.628529 │ 0.6975085437297821  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.635265 │ 0.7278340972132153  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.609763 │ 0.7193726599216461  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.612117 │ 0.6962866534789404  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.59555  │ 0.6662307977676392  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.599174 │ 0.7058895213736428  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.666699 │ 0.6787692623005973  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.668907 │ 0.6901721556981405  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.813302 │ 0.7688188652044075  │
# ├─────────────────────┼───────────┼─────────────────────┤
# ...
# │ loss_facial_hair    │ 0.0745479 │ 1.4339988402013357  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │ 0.622451  │ 0.6941522194279565  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │ 0.0416651 │ 0.24027984586104545 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │ 0.684684  │ 0.6713211337725321  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │ 0.999976  │ 0.9668417258778704  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │ 0.998574  │ 0.9725267379679144  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │ 0.997244  │ 0.768762677484787   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │ 0.990302  │ 0.735154116269996   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │ 0.988032  │ 0.8215957446808512  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │ 0.999687  │ 0.9526287654316444  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │ 0.999687  │ 0.9526287412255231  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 95: loss: 3.4017, loss_id: 3.1320, loss_gender: 0.3267, loss_da_gender: 0.5629, loss_emotion: 0.7206, loss_da_emotion: 0.7262, loss_pose: 1.0441, loss_da_pose: 0.6618, loss_facial_hair: 1.4340, loss_da_facial_hair: 0.6942, loss_spectacles: 0.2403, loss_da_spectacles: 0.6713, auc_gender: 0.9668, auc_spectacles: 0.9725, auc_facial_hair: 0.7688, auc_pose: 0.7352, auc_emotion: 0.8216, auc_id_cosine: 0.9526, auc_id_euclidean: 0.9526
#
# --- Epoch 96/100 ---
# Ep 96:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 3.48794   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 3.28185   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │ 0.0249006 │ 0.2170748524949886  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │ 0.609201  │ 0.5637912336322997  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │ 0.15292   │ 0.6771750806106461  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │ 0.672889  │ 0.719580888748169   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │ 0.136922  │ 0.8066369112994936  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │ 0.644206  │ 0.6619622972276475  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │ 0.100013  │ 1.217058872597085   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │ 0.624875  │ 0.6856830699576272  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │ 0.0432847 │ 0.21395396415351164 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │ 0.684813  │ 0.6660703751775954  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │ 0.999988  │ 0.974050046339203   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │ 0.999921  │ 0.9701871657754011  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │ 0.9982    │ 0.7472616632860041  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │ 0.990181  │ 0.716972298088178   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │ 0.99437   │ 0.8132978723404255  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │ 0.999702  │ 0.9631247817818145  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │ 0.999702  │ 0.9631247575756929  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 96: loss: 3.4879, loss_id: 3.2818, loss_gender: 0.2171, loss_da_gender: 0.5638, loss_emotion: 0.6772, loss_da_emotion: 0.7196, loss_pose: 0.8066, loss_da_pose: 0.6620, loss_facial_hair: 1.2171, loss_da_facial_hair: 0.6857, loss_spectacles: 0.2140, loss_da_spectacles: 0.6661, auc_gender: 0.9741, auc_spectacles: 0.9702, auc_facial_hair: 0.7473, auc_pose: 0.7170, auc_emotion: 0.8133, auc_id_cosine: 0.9631, auc_id_euclidean: 0.9631
# --> SAVE BEST MODEL (auc_id_cosine: 0.9631)
#
# --- Epoch 97/100 ---
# Ep 97:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 3.35456   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 3.02153   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │ 0.0232559 │ 0.20574700793561837 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │ 0.618519  │ 0.5646124945746528  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │ 0.145933  │ 0.7242218438122008  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │ 0.67697   │ 0.713871631357405   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │ 0.131707  │ 1.1720558842644095  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │ 0.648551  │ 0.6628379358185662  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │ 0.0896854 │ 1.2404743827258546  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │ 0.632796  │ 0.6860339095195135  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │ 0.0366429 │ 0.23723125531493375 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │ 0.683522  │ 0.6682466963926951  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │ 0.999861  │ 0.9740500463392029  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │ 0.999423  │ 0.9766711229946524  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │ 0.998618  │ 0.7448275862068965  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │ 0.987698  │ 0.7037846273897775  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │ 0.986747  │ 0.818936170212766   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │ 0.99969   │ 0.9549683112822022  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │ 0.99969   │ 0.9549683354883236  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 97: loss: 3.3546, loss_id: 3.0215, loss_gender: 0.2057, loss_da_gender: 0.5646, loss_emotion: 0.7242, loss_da_emotion: 0.7139, loss_pose: 1.1721, loss_da_pose: 0.6628, loss_facial_hair: 1.2405, loss_da_facial_hair: 0.6860, loss_spectacles: 0.2372, loss_da_spectacles: 0.6682, auc_gender: 0.9741, auc_spectacles: 0.9767, auc_facial_hair: 0.7448, auc_pose: 0.7038, auc_emotion: 0.8189, auc_id_cosine: 0.9550, auc_id_euclidean: 0.9550
#
# --- Epoch 98/100 ---
# Ep 98:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 3.30449   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 2.92626   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │ 0.0213763 │ 0.24713691441704416 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │ 0.619076  │ 0.571523075302442   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │ 0.144855  │ 0.6735733043816354  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │ 0.675271  │ 0.7172361380524106  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │ 0.134331  │ 1.269270119567712   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │ 0.654048  │ 0.6633164882659912  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │ 0.0722506 │ 0.7459402398930656  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │ 0.638283  │ 0.6835582322544522  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │ 0.0399782 │ 0.3351024855445657  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │ 0.683258  │ 0.6671509643395742  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │ 0.999983  │ 0.9683863659767274  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │ 0.999263  │ 0.9724598930481284  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │ 0.99803   │ 0.7657490582439873  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │ 0.994261  │ 0.7267264923917284  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │ 0.988861  │ 0.8167553191489363  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │ 0.999829  │ 0.953103495886799   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │ 0.999829  │ 0.953103495886799   │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 98: loss: 3.3045, loss_id: 2.9263, loss_gender: 0.2471, loss_da_gender: 0.5715, loss_emotion: 0.6736, loss_da_emotion: 0.7172, loss_pose: 1.2693, loss_da_pose: 0.6633, loss_facial_hair: 0.7459, loss_da_facial_hair: 0.6836, loss_spectacles: 0.3351, loss_da_spectacles: 0.6672, auc_gender: 0.9684, auc_spectacles: 0.9725, auc_facial_hair: 0.7657, auc_pose: 0.7267, auc_emotion: 0.8168, auc_id_cosine: 0.9531, auc_id_euclidean: 0.9531
#
# --- Epoch 99/100 ---
# Ep 99:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 3.26724   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 2.89448   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │ 0.0201815 │ 0.28172268118295407 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │ 0.603308  │ 0.5520636720789803  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │ 0.144917  │ 0.9318091074625651  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │ 0.669885  │ 0.7223803400993347  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │ 0.112196  │ 1.0345708057284355  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │ 0.651431  │ 0.6651145269473394  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │ 0.0776932 │ 0.8112475126981735  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │ 0.640461  │ 0.6838549160295062  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │ 0.038881  │ 0.18501783412001613 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │ 0.681037  │ 0.6650935179657407  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │ 0.999986  │ 0.9624137575944804  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │ 0.999619  │ 0.9747326203208557  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │ 0.997471  │ 0.7622718052738338  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │ 0.991316  │ 0.7253999219664456  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │ 0.989626  │ 0.8190957446808511  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │ 0.999757  │ 0.9538793989058448  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │ 0.999757  │ 0.9538793989058445  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 99: loss: 3.2672, loss_id: 2.8945, loss_gender: 0.2817, loss_da_gender: 0.5521, loss_emotion: 0.9318, loss_da_emotion: 0.7224, loss_pose: 1.0346, loss_da_pose: 0.6651, loss_facial_hair: 0.8112, loss_da_facial_hair: 0.6839, loss_spectacles: 0.1850, loss_da_spectacles: 0.6651, auc_gender: 0.9624, auc_spectacles: 0.9747, auc_facial_hair: 0.7623, auc_pose: 0.7254, auc_emotion: 0.8191, auc_id_cosine: 0.9539, auc_id_euclidean: 0.9539
#
# --- Epoch 100/100 ---
# Ep 100:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 3.18576   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 2.74024   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │ 0.021842  │ 0.29365145903041895 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │ 0.616248  │ 0.561687245965004   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │ 0.13244   │ 1.1896050133638911  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │ 0.676205  │ 0.721861203511556   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │ 0.116953  │ 0.7610671180817816  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │ 0.654441  │ 0.6663869255118899  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │ 0.0708184 │ 0.87169435289171    │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │ 0.625002  │ 0.6844589097632302  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │ 0.0376604 │ 0.2404468152154651  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │ 0.67967   │ 0.6622179680400424  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │ 0.999984  │ 0.9648851817526517  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │ 0.999249  │ 0.9772058823529413  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │ 0.995563  │ 0.7358446827006665  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │ 0.985505  │ 0.7095591104174795  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │ 0.990196  │ 0.8018617021276595  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │ 0.99973   │ 0.9558134196026595  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │ 0.99973   │ 0.9558134438087809  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 100: loss: 3.1858, loss_id: 2.7402, loss_gender: 0.2937, loss_da_gender: 0.5617, loss_emotion: 1.1896, loss_da_emotion: 0.7219, loss_pose: 0.7611, loss_da_pose: 0.6664, loss_facial_hair: 0.8717, loss_da_facial_hair: 0.6845, loss_spectacles: 0.2404, loss_da_spectacles: 0.6622, auc_gender: 0.9649, auc_spectacles: 0.9772, auc_facial_hair: 0.7358, auc_pose: 0.7096, auc_emotion: 0.8019, auc_id_cosine: 0.9558, auc_id_euclidean: 0.9558
# TRAINING HOAN TAT.
