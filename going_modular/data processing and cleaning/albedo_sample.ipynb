# %%
from google.colab import drive
import os

# 1. Mount Drive
drive.mount('/content/drive')

# 2. Clone NHÁNH convnext-v2-dev
if not os.path.exists('/content/FR_Photometric_Stereo'):
    # !git clone -b convnext-v2-dev https://github.com/minh4923/FR_Photometric_Stereo.git

# 3. Di chuyển vào thư mục dự án
# %cd /content/FR_Photometric_Stereo

# 4. Cài đặt thư viện
# !pip install -q albumentations==1.3.1 timm
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/FR_Photometric_Stereo

# %%
# %cd /content/FR_Photometric_Stereo
import warnings
warnings.filterwarnings("ignore")
import torch
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
import albumentations as A
import os
import pandas as pd

from going_modular.dataloader.multitask import create_multitask_datafetcher
from going_modular.model.MTLFaceRecognition import MTLFaceRecognition
from going_modular.loss.MultiTaskLoss import MultiTaskLoss
from going_modular.train_eval.train import fit
from going_modular.utils.transforms import RandomResizedCropRect, GaussianNoise
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint
from going_modular.utils.ExperimentManager import ExperimentManager

# --- CẤU HÌNH ---
device = "cuda" if torch.cuda.is_available() else "cpu"
seed = 42
torch.manual_seed(seed)

# Đặt tên thí nghiệm (Folder sẽ được tạo theo tên này)
EXPERIMENT_NAME = "Single_ALBEDO_Shuffle"

CONFIGURATION = {
    'note': EXPERIMENT_NAME,
    'dataset_dir': '/content/drive/MyDrive/Photometric_DB_Full/',
    'type': 'albedo',

    'device': device,
    'epochs': 120,
    'batch_size': 32,
    'image_size': 112,
    'base_lr': 1e-4,
    'backbone': 'miresnet18', # Có thể đổi thành miresnet50
    'num_classes': None,

    # Trọng số đã tối ưu (Giảm task phụ để tập trung vào ID)
    'loss_gender_weight': 1.0,      'loss_da_gender_weight': 0.1,
    'loss_emotion_weight': 0.5,     'loss_da_emotion_weight': 0.1,
    'loss_pose_weight': 1.0,        'loss_da_pose_weight': 0.1,
    'loss_spectacles_weight': 0.5,  'loss_da_spectacles_weight': 0.1,
    'loss_facial_hair_weight': 0.5, 'loss_da_facial_hair_weight': 0.1,
}

# --- 1. KHỞI TẠO MANAGER ---
manager = ExperimentManager(CONFIGURATION)
manager.log_text(f"TRAINING MODE: {CONFIGURATION['type']} | Backbone: {CONFIGURATION['backbone']}")

# --- 2. DATASET ---
train_csv_path = os.path.join(CONFIGURATION['dataset_dir'], 'dataset/train_split.csv')
if not os.path.exists(train_csv_path): train_csv_path = os.path.join(CONFIGURATION['dataset_dir'], 'train_split.csv')

# Load CSV để lấy num_classes chính xác
df_temp = pd.read_csv(train_csv_path)
CONFIGURATION['num_classes'] = df_temp['id'].max() + 1 # An toàn nhất: Max ID + 1 để tránh lỗi index out of bounds
manager.log_text(f"Max ID in CSV: {df_temp['id'].max()} -> Set num_classes: {CONFIGURATION['num_classes']}")

train_transform = A.Compose([
    RandomResizedCropRect(CONFIGURATION['image_size']),
    GaussianNoise(p=0.2), A.HorizontalFlip(p=0.5)
], additional_targets={'albedo': 'image', 'depthmap': 'image'})

test_transform = A.Compose([A.Resize(CONFIGURATION['image_size'], CONFIGURATION['image_size'])],
                           additional_targets={'albedo': 'image', 'depthmap': 'image'})

train_dl, test_dl, _ = create_multitask_datafetcher(CONFIGURATION, train_transform, test_transform)

# --- 3. MODEL & LOSS ---
model = MTLFaceRecognition(CONFIGURATION['backbone'], CONFIGURATION['num_classes'])
# Lưu ý: Truyền đúng config vào Loss để nó nhận weights mới
criterion = MultiTaskLoss(train_csv_path, CONFIGURATION)
optimizer = Adam(model.parameters(), lr=CONFIGURATION['base_lr'])
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=20, T_mult=2)

# --- 4. CHECKPOINT SAVER ---
# Lưu vào manager.ckpt_dir (experiments/.../checkpoints)
ckpt_saver = ModelCheckpoint(
    output_dir=manager.ckpt_dir,
    mode='max',
    best_metric_name='auc_id_cosine' # Model tốt nhất là model có AUC Cosine cao nhất
)

early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['cosine_auc'], patience=1500, mode='max', verbose=0,
    save_dir=manager.ckpt_dir, start_from_epoch=0
)

# --- 5. RUN ---
fit(
    conf=CONFIGURATION,
    start_epoch=0,
    model=model,
    train_dataloader=train_dl,
    test_dataloader=test_dl,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    early_stopping=early_stopping,
    model_checkpoint=ckpt_saver,
    existing_manager=manager
)
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.655968 │ 0.6701568365097046  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.355797 │ 0.526133249203364   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.606846 │ 0.6279801328976949  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.193737 │ 0.25682522190941703 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.686349 │ 0.7243497769037882  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.990254 │ 0.965400061785604   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.992186 │ 0.9612967914438504  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.917717 │ 0.8051579252390612  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.869494 │ 0.7077643386656263  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.85416  │ 0.7218617021276598  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.967003 │ 0.9221248646635746  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.967003 │ 0.9221248646635747  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 10: loss: 13.8363, loss_id: 22.8587, loss_gender: 0.3131, loss_da_gender: 0.5513, loss_emotion: 0.6624, loss_da_emotion: 0.6498, loss_pose: 0.6292, loss_da_pose: 0.6702, loss_facial_hair: 0.5261, loss_da_facial_hair: 0.6280, loss_spectacles: 0.2568, loss_da_spectacles: 0.7243, auc_gender: 0.9654, auc_spectacles: 0.9613, auc_facial_hair: 0.8052, auc_pose: 0.7078, auc_emotion: 0.7219, auc_id_cosine: 0.9221, auc_id_euclidean: 0.9221
# --> SAVE BEST MODEL (auc_id_cosine: 0.9221)
#
# --- Epoch 11/120 ---
# Ep 11:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 12.2738   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 19.8843   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.198608 │ 0.27861374285486007 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.494917 │ 0.523883988459905   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.47592  │ 0.6654255655076768  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.613444 │ 0.6554572582244873  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.441632 │ 0.6168338358402252  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.650056 │ 0.6700585352049934  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.334147 │ 0.5249099052614636  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.58987  │ 0.6289378735754225  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.164682 │ 0.2627050189508332  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.700096 │ 0.747608999411265   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.992343 │ 0.9617959015549378  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.99077  │ 0.9597593582887702  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.933543 │ 0.7991306867574616  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.90467  │ 0.6902067889192351  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.859694 │ 0.7169680851063831  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.97807  │ 0.9273240490915636  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.97807  │ 0.9273240490915636  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 11: loss: 12.2738, loss_id: 19.8843, loss_gender: 0.2786, loss_da_gender: 0.5239, loss_emotion: 0.6654, loss_da_emotion: 0.6555, loss_pose: 0.6168, loss_da_pose: 0.6701, loss_facial_hair: 0.5249, loss_da_facial_hair: 0.6289, loss_spectacles: 0.2627, loss_da_spectacles: 0.7476, auc_gender: 0.9618, auc_spectacles: 0.9598, auc_facial_hair: 0.7991, auc_pose: 0.6902, auc_emotion: 0.7170, auc_id_cosine: 0.9273, auc_id_euclidean: 0.9273
# --> SAVE BEST MODEL (auc_id_cosine: 0.9273)
#
# --- Epoch 12/120 ---
# Ep 12:
# ╒═════════════════════╤═══════════╤════════════════════╕
# │ Metric              │     Train │ Test               │
# ╞═════════════════════╪═══════════╪════════════════════╡
# │ loss                │ 11.4528   │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_id             │ 18.2834   │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_gender         │  0.177838 │ 0.2809041010008918 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_gender      │  0.494349 │ 0.5193016297287412 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_emotion        │  0.462227 │ 0.6367301775349511 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_emotion     │  0.610728 │ 0.6447732249895731 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_pose           │  0.430281 │ 0.6161509189340804 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_pose        │  0.645493 │ 0.66969985432095   │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_facial_hair    │  0.332567 │ 0.5052837365203433 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_facial_hair │  0.58783  │ 0.6335724393526713 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_spectacles     │  0.163038 │ 0.3009200377596749 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_spectacles  │  0.717838 │ 0.7306133773591783 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_gender          │  0.994439 │ 0.9416126042632067 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_spectacles      │  0.994442 │ 0.9612299465240642 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_facial_hair     │  0.94057  │ 0.8259634888438134 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_pose            │  0.904668 │ 0.711587982832618  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_emotion         │  0.875101 │ 0.7197872340425532 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_cosine       │  0.982442 │ 0.9303504194339911 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_euclidean    │  0.982442 │ 0.9303504194339911 │
# ╘═════════════════════╧═══════════╧════════════════════╛
# Ep 12: loss: 11.4528, loss_id: 18.2834, loss_gender: 0.2809, loss_da_gender: 0.5193, loss_emotion: 0.6367, loss_da_emotion: 0.6448, loss_pose: 0.6162, loss_da_pose: 0.6697, loss_facial_hair: 0.5053, loss_da_facial_hair: 0.6336, loss_spectacles: 0.3009, loss_da_spectacles: 0.7306, auc_gender: 0.9416, auc_spectacles: 0.9612, auc_facial_hair: 0.8260, auc_pose: 0.7116, auc_emotion: 0.7198, auc_id_cosine: 0.9304, auc_id_euclidean: 0.9304
# --> SAVE BEST MODEL (auc_id_cosine: 0.9304)
#
# --- Epoch 13/120 ---
# Ep 13:
# ╒═════════════════════╤═══════════╤════════════════════╕
# │ Metric              │     Train │ Test               │
# ╞═════════════════════╪═══════════╪════════════════════╡
# │ loss                │ 10.7871   │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_id             │ 17.0259   │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_gender         │  0.168127 │ 0.2594438311126497 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_gender      │  0.495069 │ 0.502420061164432  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_emotion        │  0.452946 │ 0.6424295471774207 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_emotion     │  0.604167 │ 0.6414102911949158 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_pose           │  0.416066 │ 0.5816273192564646 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_pose        │  0.640421 │ 0.6612743271721734 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_facial_hair    │  0.309636 │ 0.5059643487135569 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_facial_hair │  0.577422 │ 0.6265875001748403 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_spectacles     │  0.149065 │ 0.3419480207893584 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_spectacles  │  0.735414 │ 0.7479700379901462 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_gender          │  0.99539  │ 0.9568530532385955 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_spectacles      │  0.992701 │ 0.955614973262032  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_facial_hair     │  0.940889 │ 0.8204578383077369 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_pose            │  0.897624 │ 0.7599687865782285 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_emotion         │  0.860272 │ 0.7230851063829787 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_cosine       │  0.981191 │ 0.9345848446828737 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_euclidean    │  0.981191 │ 0.9345848204767522 │
# ╘═════════════════════╧═══════════╧════════════════════╛
# Ep 13: loss: 10.7871, loss_id: 17.0259, loss_gender: 0.2594, loss_da_gender: 0.5024, loss_emotion: 0.6424, loss_da_emotion: 0.6414, loss_pose: 0.5816, loss_da_pose: 0.6613, loss_facial_hair: 0.5060, loss_da_facial_hair: 0.6266, loss_spectacles: 0.3419, loss_da_spectacles: 0.7480, auc_gender: 0.9569, auc_spectacles: 0.9556, auc_facial_hair: 0.8205, auc_pose: 0.7600, auc_emotion: 0.7231, auc_id_cosine: 0.9346, auc_id_euclidean: 0.9346
# --> SAVE BEST MODEL (auc_id_cosine: 0.9346)
#
# --- Epoch 14/120 ---
# Ep 14:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │ 10.0071   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 15.5018   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.157699 │ 0.2656383299165302  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.500568 │ 0.5060710178481208  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.448384 │ 0.6568624940183427  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.604241 │ 0.6532796025276184  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.409413 │ 0.5854095651043786  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.630841 │ 0.6612030797534518  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.304728 │ 0.48194332751962876 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.571408 │ 0.6179041862487793  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.151328 │ 0.23893357316652933 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.733808 │ 0.7449849645296732  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.996885 │ 0.9544846050870148  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.993805 │ 0.9650401069518718  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.953553 │ 0.8288032454361054  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.912278 │ 0.75598907530238    │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.883115 │ 0.7194148936170214  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.984297 │ 0.9366772218266404  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.984297 │ 0.9366771976205189  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 14: loss: 10.0071, loss_id: 15.5018, loss_gender: 0.2656, loss_da_gender: 0.5061, loss_emotion: 0.6569, loss_da_emotion: 0.6533, loss_pose: 0.5854, loss_da_pose: 0.6612, loss_facial_hair: 0.4819, loss_da_facial_hair: 0.6179, loss_spectacles: 0.2389, loss_da_spectacles: 0.7450, auc_gender: 0.9545, auc_spectacles: 0.9650, auc_facial_hair: 0.8288, auc_pose: 0.7560, auc_emotion: 0.7194, auc_id_cosine: 0.9367, auc_id_euclidean: 0.9367
# --> SAVE BEST MODEL (auc_id_cosine: 0.9367)
#
# --- Epoch 15/120 ---
# Ep 15:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │  9.53695  │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 14.6033   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.151238 │ 0.24464846154054007 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.508325 │ 0.49578723642561173 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.443096 │ 0.6633239156670041  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.599561 │ 0.654129683971405   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.382278 │ 0.6036855545308855  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.630906 │ 0.6688110166125827  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.298534 │ 0.49554600980546737 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.572066 │ 0.6223026315371195  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.145556 │ 0.25373737182882095 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.739091 │ 0.7550773223241171  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.998558 │ 0.9639583976933376  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.99393  │ 0.9654411764705884  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.95365  │ 0.8223703274413214  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.921044 │ 0.7280530628170114  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.867291 │ 0.716436170212766   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.985003 │ 0.9395520376422619  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.985003 │ 0.9395520376422619  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 15: loss: 9.5370, loss_id: 14.6033, loss_gender: 0.2446, loss_da_gender: 0.4958, loss_emotion: 0.6633, loss_da_emotion: 0.6541, loss_pose: 0.6037, loss_da_pose: 0.6688, loss_facial_hair: 0.4955, loss_da_facial_hair: 0.6223, loss_spectacles: 0.2537, loss_da_spectacles: 0.7551, auc_gender: 0.9640, auc_spectacles: 0.9654, auc_facial_hair: 0.8224, auc_pose: 0.7281, auc_emotion: 0.7164, auc_id_cosine: 0.9396, auc_id_euclidean: 0.9396
# --> SAVE BEST MODEL (auc_id_cosine: 0.9396)
#
# --- Epoch 16/120 ---
# Ep 16:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │  8.83822  │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 13.2338   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.133489 │ 0.2574462642272313  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.519366 │ 0.5124025079939101  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.447681 │ 0.6608536243438721  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.60087  │ 0.6542068587409126  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.383452 │ 0.5881846050421397  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.629546 │ 0.6637280848291185  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.276374 │ 0.484452744325002   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.561538 │ 0.6219204432434506  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.147474 │ 0.25057419389486313 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.742835 │ 0.746821297539605   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.995816 │ 0.9556173411595098  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.993928 │ 0.9621657754010696  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.958574 │ 0.8265430310055056  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.91935  │ 0.7448302770191182  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.878904 │ 0.7275              │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.984141 │ 0.9407540168122165  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.984141 │ 0.9407539926060948  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 16: loss: 8.8382, loss_id: 13.2338, loss_gender: 0.2574, loss_da_gender: 0.5124, loss_emotion: 0.6609, loss_da_emotion: 0.6542, loss_pose: 0.5882, loss_da_pose: 0.6637, loss_facial_hair: 0.4845, loss_da_facial_hair: 0.6219, loss_spectacles: 0.2506, loss_da_spectacles: 0.7468, auc_gender: 0.9556, auc_spectacles: 0.9622, auc_facial_hair: 0.8265, auc_pose: 0.7448, auc_emotion: 0.7275, auc_id_cosine: 0.9408, auc_id_euclidean: 0.9408
# --> SAVE BEST MODEL (auc_id_cosine: 0.9408)
#
# --- Epoch 17/120 ---
# Ep 17:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │  8.56255  │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 12.692    │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.140571 │ 0.2658989429473877  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.518314 │ 0.5171319544315338  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.435583 │ 0.6649316781096988  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.599236 │ 0.6570682062043084  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.376503 │ 0.594066858291626   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.629423 │ 0.6659598549207052  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.281985 │ 0.4835947851339976  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.566641 │ 0.6188455190923479  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.141891 │ 0.23159795833958519 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.742984 │ 0.7547300789091322  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.997933 │ 0.9524250849552054  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.997451 │ 0.9642379679144384  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.961097 │ 0.8299043755433209  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.942432 │ 0.743815840811549   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.872652 │ 0.7202659574468085  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.986697 │ 0.9417328155418017  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.986697 │ 0.9417328155418018  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 17: loss: 8.5626, loss_id: 12.6920, loss_gender: 0.2659, loss_da_gender: 0.5171, loss_emotion: 0.6649, loss_da_emotion: 0.6571, loss_pose: 0.5941, loss_da_pose: 0.6660, loss_facial_hair: 0.4836, loss_da_facial_hair: 0.6188, loss_spectacles: 0.2316, loss_da_spectacles: 0.7547, auc_gender: 0.9524, auc_spectacles: 0.9642, auc_facial_hair: 0.8299, auc_pose: 0.7438, auc_emotion: 0.7203, auc_id_cosine: 0.9417, auc_id_euclidean: 0.9417
# --> SAVE BEST MODEL (auc_id_cosine: 0.9417)
#
# --- Epoch 18/120 ---
# Ep 18:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │  8.34475  │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 12.2647   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.13501  │ 0.2733200904395845  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.522871 │ 0.5179692010084788  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.424861 │ 0.661875327428182   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.594561 │ 0.6558682256274753  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.384462 │ 0.5862705243958367  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.629196 │ 0.6636977394421896  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.288826 │ 0.49198859102196163 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.564831 │ 0.6208160718282064  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.126712 │ 0.26094672083854675 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.753462 │ 0.7562194135453966  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.998569 │ 0.9501596128102152  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.994064 │ 0.9630347593582889  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.962211 │ 0.8332077658649667  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.93174  │ 0.7602028872415139  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.892504 │ 0.7218617021276597  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.987136 │ 0.9422741612433657  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.987136 │ 0.9422742096556088  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 18: loss: 8.3448, loss_id: 12.2647, loss_gender: 0.2733, loss_da_gender: 0.5180, loss_emotion: 0.6619, loss_da_emotion: 0.6559, loss_pose: 0.5863, loss_da_pose: 0.6637, loss_facial_hair: 0.4920, loss_da_facial_hair: 0.6208, loss_spectacles: 0.2609, loss_da_spectacles: 0.7562, auc_gender: 0.9502, auc_spectacles: 0.9630, auc_facial_hair: 0.8332, auc_pose: 0.7602, auc_emotion: 0.7219, auc_id_cosine: 0.9423, auc_id_euclidean: 0.9423
# --> SAVE BEST MODEL (auc_id_cosine: 0.9423)
#
# --- Epoch 19/120 ---
# Ep 19:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │  8.28127  │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 12.1563   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.128505 │ 0.25232556296719444 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.538135 │ 0.5149949524137709  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.428316 │ 0.6658516459994845  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.59843  │ 0.6571082406573825  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.362016 │ 0.594396001762814   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.630832 │ 0.6638073921203613  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.284712 │ 0.4762568109565311  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.563637 │ 0.6207759943273332  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.120073 │ 0.24547493954499564 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.75154  │ 0.7549917234314812  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.997865 │ 0.9581917413242715  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.993815 │ 0.9625668449197861  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.968861 │ 0.8348884381338743  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.947956 │ 0.7560671088568084  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.882702 │ 0.7223936170212766  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.988976 │ 0.9431890073999082  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.988976 │ 0.9431890073999081  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 19: loss: 8.2813, loss_id: 12.1563, loss_gender: 0.2523, loss_da_gender: 0.5150, loss_emotion: 0.6659, loss_da_emotion: 0.6571, loss_pose: 0.5944, loss_da_pose: 0.6638, loss_facial_hair: 0.4763, loss_da_facial_hair: 0.6208, loss_spectacles: 0.2455, loss_da_spectacles: 0.7550, auc_gender: 0.9582, auc_spectacles: 0.9626, auc_facial_hair: 0.8349, auc_pose: 0.7561, auc_emotion: 0.7224, auc_id_cosine: 0.9432, auc_id_euclidean: 0.9432
# --> SAVE BEST MODEL (auc_id_cosine: 0.9432)
#
# --- Epoch 20/120 ---
# Ep 20:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │  8.13559  │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 11.8698   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.127636 │ 0.25608469545841217 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.519087 │ 0.5172430674235026  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.443574 │ 0.6644545959101783  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.600899 │ 0.6564499802059598  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.378284 │ 0.5964344077640109  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.623635 │ 0.6652976274490356  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.269474 │ 0.48311815824773574 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.559425 │ 0.6213089327017466  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.128574 │ 0.24014251016908222 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.750846 │ 0.7537165880203247  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.997741 │ 0.9562351971990526  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.994796 │ 0.9632352941176471  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.959273 │ 0.8332077658649666  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.941547 │ 0.7452984783456887  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.875103 │ 0.7181914893617021  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.987489 │ 0.9433131848032807  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.987489 │ 0.9433131848032807  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 20: loss: 8.1356, loss_id: 11.8698, loss_gender: 0.2561, loss_da_gender: 0.5172, loss_emotion: 0.6645, loss_da_emotion: 0.6564, loss_pose: 0.5964, loss_da_pose: 0.6653, loss_facial_hair: 0.4831, loss_da_facial_hair: 0.6213, loss_spectacles: 0.2401, loss_da_spectacles: 0.7537, auc_gender: 0.9562, auc_spectacles: 0.9632, auc_facial_hair: 0.8332, auc_pose: 0.7453, auc_emotion: 0.7182, auc_id_cosine: 0.9433, auc_id_euclidean: 0.9433
# --> SAVE BEST MODEL (auc_id_cosine: 0.9433)
#
# --- Epoch 21/120 ---
# Ep 21:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │  8.28106  │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 12.1093   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.13892  │ 0.25630296270052594 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.520791 │ 0.5165196789635552  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.439368 │ 0.6614451143476698  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.598841 │ 0.6569734613100687  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.388979 │ 0.5930009881655375  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.627779 │ 0.665131946404775   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.283444 │ 0.4806618044773738  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.563185 │ 0.6200171179241605  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.140969 │ 0.23977280408143997 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.75053  │ 0.7552264200316535  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.998655 │ 0.9560292451858716  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.992019 │ 0.9644385026737968  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.964085 │ 0.8317009562445669  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.944933 │ 0.749434256730394   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.87774  │ 0.723191489361702   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.987222 │ 0.9439356694241634  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.987222 │ 0.943935645218042   │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 21: loss: 8.2811, loss_id: 12.1093, loss_gender: 0.2563, loss_da_gender: 0.5165, loss_emotion: 0.6614, loss_da_emotion: 0.6570, loss_pose: 0.5930, loss_da_pose: 0.6651, loss_facial_hair: 0.4807, loss_da_facial_hair: 0.6200, loss_spectacles: 0.2398, loss_da_spectacles: 0.7552, auc_gender: 0.9560, auc_spectacles: 0.9644, auc_facial_hair: 0.8317, auc_pose: 0.7494, auc_emotion: 0.7232, auc_id_cosine: 0.9439, auc_id_euclidean: 0.9439
# --> SAVE BEST MODEL (auc_id_cosine: 0.9439)
#
# --- Epoch 22/120 ---
# Ep 22:
# ╒═════════════════════╤═══════════╤════════════════════╕
# │ Metric              │     Train │ Test               │
# ╞═════════════════════╪═══════════╪════════════════════╡
# │ loss                │  9.18679  │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_id             │ 14.0252   │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_gender         │  0.136647 │ 0.2783224168750975 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_gender      │  0.512419 │ 0.5147262480523851 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_emotion        │  0.433872 │ 0.6999948488341438 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_emotion     │  0.589206 │ 0.6605675750308566 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_pose           │  0.377342 │ 0.6179744005203247 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_pose        │  0.621253 │ 0.6585561169518365 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_facial_hair    │  0.277115 │ 0.5049459445807669 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_facial_hair │  0.544315 │ 0.6048630144861009 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_spectacles     │  0.138285 │ 0.3015977376037174 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_spectacles  │  0.717939 │ 0.7089301612642076 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_gender          │  0.994874 │ 0.9429512923488826 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_spectacles      │  0.989229 │ 0.9540775401069519 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_facial_hair     │  0.937934 │ 0.821501014198783  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_pose            │  0.922566 │ 0.7552087397580961 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_emotion         │  0.865523 │ 0.6942021276595745 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_cosine       │  0.98383  │ 0.9344286183746151 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_euclidean    │  0.98383  │ 0.9344286667868581 │
# ╘═════════════════════╧═══════════╧════════════════════╛
# Ep 22: loss: 9.1868, loss_id: 14.0252, loss_gender: 0.2783, loss_da_gender: 0.5147, loss_emotion: 0.7000, loss_da_emotion: 0.6606, loss_pose: 0.6180, loss_da_pose: 0.6586, loss_facial_hair: 0.5049, loss_da_facial_hair: 0.6049, loss_spectacles: 0.3016, loss_da_spectacles: 0.7089, auc_gender: 0.9430, auc_spectacles: 0.9541, auc_facial_hair: 0.8215, auc_pose: 0.7552, auc_emotion: 0.6942, auc_id_cosine: 0.9344, auc_id_euclidean: 0.9344
#
# --- Epoch 23/120 ---
# Ep 23:
# ╒═════════════════════╤═══════════╤════════════════════╕
# │ Metric              │     Train │ Test               │
# ╞═════════════════════╪═══════════╪════════════════════╡
# │ loss                │  8.76496  │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_id             │ 13.334    │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_gender         │  0.113974 │ 0.2630519113606877 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_gender      │  0.522538 │ 0.4810721178849538 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_emotion        │  0.410795 │ 0.7171759174929725 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_emotion     │  0.571673 │ 0.6807519263691373 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_pose           │  0.351903 │ 0.6594876315858629 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_pose        │  0.601618 │ 0.6622741288608975 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_facial_hair    │  0.272616 │ 0.4847656538089116 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_facial_hair │  0.522775 │ 0.6034006873766581 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_spectacles     │  0.124428 │ 0.4569539162847731 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_spectacles  │  0.703564 │ 0.7032042476865981 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_gender          │  0.995529 │ 0.9527340129749768 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_spectacles      │  0.991866 │ 0.9619652406417113 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_facial_hair     │  0.960807 │ 0.827933932193567  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_pose            │  0.931852 │ 0.7316426063207179 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_emotion         │  0.878568 │ 0.6965425531914894 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_cosine       │  0.983273 │ 0.923961262072319  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_euclidean    │  0.983273 │ 0.9239612620723189 │
# ╘═════════════════════╧═══════════╧════════════════════╛
# Ep 23: loss: 8.7650, loss_id: 13.3340, loss_gender: 0.2631, loss_da_gender: 0.4811, loss_emotion: 0.7172, loss_da_emotion: 0.6808, loss_pose: 0.6595, loss_da_pose: 0.6623, loss_facial_hair: 0.4848, loss_da_facial_hair: 0.6034, loss_spectacles: 0.4570, loss_da_spectacles: 0.7032, auc_gender: 0.9527, auc_spectacles: 0.9620, auc_facial_hair: 0.8279, auc_pose: 0.7316, auc_emotion: 0.6965, auc_id_cosine: 0.9240, auc_id_euclidean: 0.9240
#
# --- Epoch 24/120 ---
# Ep 24:
# ╒═════════════════════╤═══════════╤════════════════════╕
# │ Metric              │     Train │ Test               │
# ╞═════════════════════╪═══════════╪════════════════════╡
# │ loss                │  8.22091  │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_id             │ 12.2181   │ -                  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_gender         │  0.111922 │ 0.2826731577515602 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_gender      │  0.55334  │ 0.5204740199777815 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_emotion        │  0.412378 │ 0.732716742489073  │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_emotion     │  0.572821 │ 0.6790623333719041 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_pose           │  0.354955 │ 0.6105847458044688 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_pose        │  0.607525 │ 0.6539792352252536 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_facial_hair    │  0.260493 │ 0.5482588046126895 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_facial_hair │  0.520459 │ 0.6115260124206543 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_spectacles     │  0.119668 │ 0.2504326072004106 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ loss_da_spectacles  │  0.710195 │ 0.6987825168503655 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_gender          │  0.998053 │ 0.9427453403357018 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_spectacles      │  0.995283 │ 0.9592914438502674 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_facial_hair     │  0.955298 │ 0.7969863807592003 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_pose            │  0.933515 │ 0.7271166601638704 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_emotion         │  0.892948 │ 0.7136170212765958 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_cosine       │  0.988225 │ 0.9418720491527567 │
# ├─────────────────────┼───────────┼────────────────────┤
# │ auc_id_euclidean    │  0.988225 │ 0.9418720733588781 │
# ╘═════════════════════╧═══════════╧════════════════════╛
# Ep 24: loss: 8.2209, loss_id: 12.2181, loss_gender: 0.2827, loss_da_gender: 0.5205, loss_emotion: 0.7327, loss_da_emotion: 0.6791, loss_pose: 0.6106, loss_da_pose: 0.6540, loss_facial_hair: 0.5483, loss_da_facial_hair: 0.6115, loss_spectacles: 0.2504, loss_da_spectacles: 0.6988, auc_gender: 0.9427, auc_spectacles: 0.9593, auc_facial_hair: 0.7970, auc_pose: 0.7271, auc_emotion: 0.7136, auc_id_cosine: 0.9419, auc_id_euclidean: 0.9419
#
# --- Epoch 25/120 ---
# Ep 25:
# ╒═════════════════════╤═══════════╤═════════════════════╕
# │ Metric              │     Train │ Test                │
# ╞═════════════════════╪═══════════╪═════════════════════╡
# │ loss                │  7.74528  │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_id             │ 11.3286   │ -                   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_gender         │  0.102553 │ 0.23778220266103745 │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_gender      │  0.591079 │ 0.5519983470439911  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_emotion        │  0.403826 │ 0.7169563273588816  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_emotion     │  0.568097 │ 0.6759811507331001  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_pose           │  0.342928 │ 0.6468562251991696  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_pose        │  0.606339 │ 0.6768519481023153  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_facial_hair    │  0.229614 │ 0.517399801976151   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.499776 │ 0.6234533455636766  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_spectacles     │  0.106447 │ 0.2276871750752131  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.711265 │ 0.7040115065044827  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_gender          │  0.998707 │ 0.9554113891463288  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_spectacles      │  0.995316 │ 0.967379679144385   │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_facial_hair     │  0.975948 │ 0.8156476383656911  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_pose            │  0.942478 │ 0.6858369098712447  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_emotion         │  0.889587 │ 0.7022872340425532  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_cosine       │  0.990162 │ 0.9309887832705879  │
# ├─────────────────────┼───────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.990162 │ 0.9309887348583448  │
# ╘═════════════════════╧═══════════╧═════════════════════╛
# Ep 25: loss: 7.7453, loss_id: 11.3286, loss_gender: 0.2378, loss_da_gender: 0.5520, loss_emotion: 0.7170, loss_da_emotion: 0.6760, loss_pose: 0.6469, loss_da_pose: 0.6769, loss_facial_hair: 0.5174, loss_da_facial_hair: 0.6235, loss_spectacles: 0.2277, loss_da_spectacles: 0.7040, auc_gender: 0.9554, auc_spectacles: 0.9674, auc_facial_hair: 0.8156, auc_pose: 0.6858, auc_emotion: 0.7023, auc_id_cosine: 0.9310, auc_id_euclidean: 0.9310
#
# --- Epoch 26/120 ---
# Ep 26:
# ╒═════════════════════╤════════════╤═════════════════════╕
# │ Metric              │      Train │ Test                │
# ╞═════════════════════╪════════════╪═════════════════════╡
# │ loss                │  7.22124   │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_id             │ 10.266     │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_gender         │  0.0876109 │ 0.25547805345720714 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_gender      │  0.630716  │ 0.5668050381872389  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_emotion        │  0.394264  │ 0.6935261487960815  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_emotion     │  0.577321  │ 0.6650554140408834  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_pose           │  0.322395  │ 0.6984526680575477  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_pose        │  0.609802  │ 0.6655075483851962  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair    │  0.23238   │ 0.5056899570756488  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.515609  │ 0.6427678532070584  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles     │  0.09888   │ 0.20806635295351347 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.707476  │ 0.7039245896869235  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_gender          │  0.998656  │ 0.9516012769024818  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles      │  0.996986  │ 0.9661096256684492  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair     │  0.976753  │ 0.8209214720370906  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_pose            │  0.955351  │ 0.6645337495122903  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_emotion         │  0.909351  │ 0.7294148936170214  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine       │  0.99216   │ 0.9475526933376814  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.99216   │ 0.9475526933376813  │
# ╘═════════════════════╧════════════╧═════════════════════╛
# Ep 26: loss: 7.2212, loss_id: 10.2660, loss_gender: 0.2555, loss_da_gender: 0.5668, loss_emotion: 0.6935, loss_da_emotion: 0.6651, loss_pose: 0.6985, loss_da_pose: 0.6655, loss_facial_hair: 0.5057, loss_da_facial_hair: 0.6428, loss_spectacles: 0.2081, loss_da_spectacles: 0.7039, auc_gender: 0.9516, auc_spectacles: 0.9661, auc_facial_hair: 0.8209, auc_pose: 0.6645, auc_emotion: 0.7294, auc_id_cosine: 0.9476, auc_id_euclidean: 0.9476
# --> SAVE BEST MODEL (auc_id_cosine: 0.9476)
#
# --- Epoch 27/120 ---
# Ep 27:
# ╒═════════════════════╤═══════════╤════════════════════╕
# │ Metric              │     Train │ Test               │
# ...
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles     │ 0.0128992  │ 0.22337541982738507 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_spectacles  │ 0.685154   │ 0.6666984094513787  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_gender          │ 1          │ 0.9354340438677788  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles      │ 0.999506   │ 0.973529411764706   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair     │ 0.999969   │ 0.793103448275862   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_pose            │ 0.999554   │ 0.7104955130706204  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_emotion         │ 0.993543   │ 0.746595744680851   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine       │ 0.99999    │ 0.9561753495315535  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean    │ 0.99999    │ 0.9561753011193103  │
# ╘═════════════════════╧════════════╧═════════════════════╛
# Ep 115: loss: 2.5212, loss_id: 1.6892, loss_gender: 0.3239, loss_da_gender: 0.5665, loss_emotion: 2.3947, loss_da_emotion: 0.7151, loss_pose: 1.1451, loss_da_pose: 0.6743, loss_facial_hair: 1.0313, loss_da_facial_hair: 0.6689, loss_spectacles: 0.2234, loss_da_spectacles: 0.6667, auc_gender: 0.9354, auc_spectacles: 0.9735, auc_facial_hair: 0.7931, auc_pose: 0.7105, auc_emotion: 0.7466, auc_id_cosine: 0.9562, auc_id_euclidean: 0.9562
#
# --- Epoch 116/120 ---
# Ep 116:
# ╒═════════════════════╤════════════╤═════════════════════╕
# │ Metric              │      Train │ Test                │
# ╞═════════════════════╪════════════╪═════════════════════╡
# │ loss                │ 2.49091    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_id             │ 1.64655    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_gender         │ 0.00252483 │ 0.33103808098369175 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_gender      │ 0.614994   │ 0.5678342150317298  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_emotion        │ 0.051264   │ 2.305988974041409   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_emotion     │ 0.670319   │ 0.7149206664827135  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_pose           │ 0.0360393  │ 1.1892332368426852  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_pose        │ 0.649316   │ 0.6753753887282478  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair    │ 0.018242   │ 1.0386048526399665  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_facial_hair │ 0.604439   │ 0.6694426006740994  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles     │ 0.00722268 │ 0.2376030409294698  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_spectacles  │ 0.680909   │ 0.6696387396918403  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_gender          │ 1          │ 0.9373390999897024  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles      │ 1          │ 0.9729278074866311  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair     │ 0.99998    │ 0.7921761808171544  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_pose            │ 0.999346   │ 0.7208739758095981  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_emotion         │ 0.995092   │ 0.7563829787234042  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine       │ 0.999992   │ 0.9555215906016732  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean    │ 0.999992   │ 0.9555215663955516  │
# ╘═════════════════════╧════════════╧═════════════════════╛
# Ep 116: loss: 2.4909, loss_id: 1.6466, loss_gender: 0.3310, loss_da_gender: 0.5678, loss_emotion: 2.3060, loss_da_emotion: 0.7149, loss_pose: 1.1892, loss_da_pose: 0.6754, loss_facial_hair: 1.0386, loss_da_facial_hair: 0.6694, loss_spectacles: 0.2376, loss_da_spectacles: 0.6696, auc_gender: 0.9373, auc_spectacles: 0.9729, auc_facial_hair: 0.7922, auc_pose: 0.7209, auc_emotion: 0.7564, auc_id_cosine: 0.9555, auc_id_euclidean: 0.9555
#
# --- Epoch 117/120 ---
# Ep 117:
# ╒═════════════════════╤════════════╤════════════════════╕
# │ Metric              │      Train │ Test               │
# ╞═════════════════════╪════════════╪════════════════════╡
# │ loss                │ 2.47333    │ -                  │
# ├─────────────────────┼────────────┼────────────────────┤
# │ loss_id             │ 1.60074    │ -                  │
# ├─────────────────────┼────────────┼────────────────────┤
# │ loss_gender         │ 0.00527981 │ 0.3071481881456243 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ loss_da_gender      │ 0.606295   │ 0.5654781427648332 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ loss_emotion        │ 0.0584088  │ 2.368996262550354  │
# ├─────────────────────┼────────────┼────────────────────┤
# │ loss_da_emotion     │ 0.675872   │ 0.7158407171567281 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ loss_pose           │ 0.0343856  │ 1.2307554483413696 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ loss_da_pose        │ 0.647777   │ 0.6755011545287238 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ loss_facial_hair    │ 0.00919736 │ 0.9739982990754975 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ loss_da_facial_hair │ 0.614738   │ 0.6693074272738563 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ loss_spectacles     │ 0.0114131  │ 0.2526349318213761 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ loss_da_spectacles  │ 0.682565   │ 0.6692902445793152 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ auc_gender          │ 1          │ 0.9424879003192256 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ auc_spectacles      │ 1          │ 0.9689171122994653 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ auc_facial_hair     │ 0.999986   │ 0.7999420457838308 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ auc_pose            │ 0.998148   │ 0.7078423722200545 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ auc_emotion         │ 0.995627   │ 0.7487765957446807 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ auc_id_cosine       │ 0.999999   │ 0.9589113674464073 │
# ├─────────────────────┼────────────┼────────────────────┤
# │ auc_id_euclidean    │ 0.999999   │ 0.9589113674464073 │
# ╘═════════════════════╧════════════╧════════════════════╛
# Ep 117: loss: 2.4733, loss_id: 1.6007, loss_gender: 0.3071, loss_da_gender: 0.5655, loss_emotion: 2.3690, loss_da_emotion: 0.7158, loss_pose: 1.2308, loss_da_pose: 0.6755, loss_facial_hair: 0.9740, loss_da_facial_hair: 0.6693, loss_spectacles: 0.2526, loss_da_spectacles: 0.6693, auc_gender: 0.9425, auc_spectacles: 0.9689, auc_facial_hair: 0.7999, auc_pose: 0.7078, auc_emotion: 0.7488, auc_id_cosine: 0.9589, auc_id_euclidean: 0.9589
#
# --- Epoch 118/120 ---
# Ep 118:
# ╒═════════════════════╤════════════╤═════════════════════╕
# │ Metric              │      Train │ Test                │
# ╞═════════════════════╪════════════╪═════════════════════╡
# │ loss                │ 2.47458    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_id             │ 1.63025    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_gender         │ 0.00497908 │ 0.3363198321312666  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_gender      │ 0.614118   │ 0.5652490324444241  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_emotion        │ 0.0534293  │ 2.4456707239151     │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_emotion     │ 0.672064   │ 0.7150231069988675  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_pose           │ 0.0279609  │ 1.2006205469369888  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_pose        │ 0.637978   │ 0.6756776306364272  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair    │ 0.0147748  │ 0.9611495667033725  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_facial_hair │ 0.602442   │ 0.6710052953826057  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles     │ 0.00617257 │ 0.23643885019959676 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_spectacles  │ 0.685002   │ 0.6675484908951653  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_gender          │ 1          │ 0.9351766038513025  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles      │ 0.999966   │ 0.9707887700534761  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair     │ 0.999898   │ 0.7988409156766155  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_pose            │ 0.999784   │ 0.706749902458057   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_emotion         │ 0.996857   │ 0.7492021276595744  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine       │ 0.999489   │ 0.9611827246526565  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean    │ 0.999489   │ 0.9611827004465352  │
# ╘═════════════════════╧════════════╧═════════════════════╛
# Ep 118: loss: 2.4746, loss_id: 1.6302, loss_gender: 0.3363, loss_da_gender: 0.5652, loss_emotion: 2.4457, loss_da_emotion: 0.7150, loss_pose: 1.2006, loss_da_pose: 0.6757, loss_facial_hair: 0.9611, loss_da_facial_hair: 0.6710, loss_spectacles: 0.2364, loss_da_spectacles: 0.6675, auc_gender: 0.9352, auc_spectacles: 0.9708, auc_facial_hair: 0.7988, auc_pose: 0.7067, auc_emotion: 0.7492, auc_id_cosine: 0.9612, auc_id_euclidean: 0.9612
#
# --- Epoch 119/120 ---
# Ep 119:
# ╒═════════════════════╤════════════╤═════════════════════╕
# │ Metric              │      Train │ Test                │
# ╞═════════════════════╪════════════╪═════════════════════╡
# │ loss                │ 2.45943    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_id             │ 1.59818    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_gender         │ 0.0034291  │ 0.32613082105914754 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_gender      │ 0.59463    │ 0.5643306208981408  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_emotion        │ 0.0433523  │ 2.317071649763319   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_emotion     │ 0.668444   │ 0.7163926031854417  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_pose           │ 0.0400731  │ 1.0089737756384745  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_pose        │ 0.651264   │ 0.6754666699303521  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair    │ 0.0108078  │ 1.0204925036264791  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_facial_hair │ 0.615946   │ 0.6707211070590549  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles     │ 0.00498168 │ 0.2470944698693024  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_spectacles  │ 0.687746   │ 0.6655106743176779  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_gender          │ 1          │ 0.93347749974256    │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles      │ 0.999987   │ 0.9701203208556148  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair     │ 0.999797   │ 0.7909011880614315  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_pose            │ 0.999454   │ 0.7268045259461569  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_emotion         │ 0.995305   │ 0.7385638297872341  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine       │ 0.999993   │ 0.9610096750899451  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean    │ 0.999993   │ 0.9610096508838236  │
# ╘═════════════════════╧════════════╧═════════════════════╛
# Ep 119: loss: 2.4594, loss_id: 1.5982, loss_gender: 0.3261, loss_da_gender: 0.5643, loss_emotion: 2.3171, loss_da_emotion: 0.7164, loss_pose: 1.0090, loss_da_pose: 0.6755, loss_facial_hair: 1.0205, loss_da_facial_hair: 0.6707, loss_spectacles: 0.2471, loss_da_spectacles: 0.6655, auc_gender: 0.9335, auc_spectacles: 0.9701, auc_facial_hair: 0.7909, auc_pose: 0.7268, auc_emotion: 0.7386, auc_id_cosine: 0.9610, auc_id_euclidean: 0.9610
#
# --- Epoch 120/120 ---
# Ep 120:
# ╒═════════════════════╤════════════╤═════════════════════╕
# │ Metric              │      Train │ Test                │
# ╞═════════════════════╪════════════╪═════════════════════╡
# │ loss                │ 2.44446    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_id             │ 1.58306    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_gender         │ 0.00335583 │ 0.2870654943916533  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_gender      │ 0.59385    │ 0.5624427364932166  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_emotion        │ 0.0498738  │ 2.453151437971327   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_emotion     │ 0.675794   │ 0.7160138090451559  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_pose           │ 0.0402247  │ 1.1232216937674417  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_pose        │ 0.645459   │ 0.675536122586992   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair    │ 0.012219   │ 1.0185618085993662  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_facial_hair │ 0.592542   │ 0.6710311240620084  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles     │ 0.0108704  │ 0.23452403225625554 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_spectacles  │ 0.68167    │ 0.6656382017665439  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_gender          │ 1          │ 0.9400679641643498  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles      │ 1          │ 0.9727941176470588  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair     │ 0.999978   │ 0.7860330339032163  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_pose            │ 0.999703   │ 0.7059695669137729  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_emotion         │ 0.99707    │ 0.7366489361702128  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine       │ 0.999927   │ 0.960083331025683   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean    │ 0.999927   │ 0.9600833310256831  │
# ╘═════════════════════╧════════════╧═════════════════════╛
# Ep 120: loss: 2.4445, loss_id: 1.5831, loss_gender: 0.2871, loss_da_gender: 0.5624, loss_emotion: 2.4532, loss_da_emotion: 0.7160, loss_pose: 1.1232, loss_da_pose: 0.6755, loss_facial_hair: 1.0186, loss_da_facial_hair: 0.6710, loss_spectacles: 0.2345, loss_da_spectacles: 0.6656, auc_gender: 0.9401, auc_spectacles: 0.9728, auc_facial_hair: 0.7860, auc_pose: 0.7060, auc_emotion: 0.7366, auc_id_cosine: 0.9601, auc_id_euclidean: 0.9601
# TRAINING HOAN TAT.
