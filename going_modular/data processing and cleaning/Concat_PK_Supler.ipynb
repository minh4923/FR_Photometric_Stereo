# %%
from google.colab import drive
import os

# 1. Mount Drive
drive.mount('/content/drive')

# 2. Clone NHÁNH convnext-v2-dev
if not os.path.exists('/content/FR_Photometric_Stereo'):
    # !git clone -b convnext-v2-dev https://github.com/minh4923/FR_Photometric_Stereo.git

# 3. Di chuyển vào thư mục dự án
# %cd /content/FR_Photometric_Stereo

# 4. Cài đặt thư viện
# !pip install -q albumentations==1.3.1 timm
# Out:
# Mounted at /content/drive
# Cloning into 'FR_Photometric_Stereo'...
# remote: Enumerating objects: 142, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 142 (delta 48), reused 132 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (142/142), 10.79 MiB | 33.09 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/FR_Photometric_Stereo
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.7/125.7 kB 4.5 MB/s eta 0:00:00

# %%
# %cd /content/FR_Photometric_Stereo
import warnings
warnings.filterwarnings("ignore")
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
import albumentations as A
import os
import torch
import pandas as pd

from going_modular.dataloader.multitask import create_concatv2_multitask_datafetcher
from going_modular.model.MTLFaceRecognition import MTLFaceRecognition
from going_modular.model.ConcatMTLFaceRecognition import ConcatMTLFaceRecognitionV2
from going_modular.loss.ConcatMultiTaskLoss import ConcatMultiTaskLoss
from going_modular.train_eval.concat_train import fit
from going_modular.utils.transforms import RandomResizedCropRect, GaussianNoise
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint
from going_modular.utils.ExperimentManager import ExperimentManager

device = "cuda" if torch.cuda.is_available() else "cpu"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Đặt seed toàn cục
seed = 42
torch.manual_seed(seed)

# --- TÊN THÍ NGHIỆM ---
EXPERIMENT_NAME = "Concat_ALBEDO_NORMAL_Shuffle"

CONFIGURATION = {
    'note': EXPERIMENT_NAME,
    'type': 'concat_v2',

    # CÔNG TẮC SHUFFLE
    'use_sampler': False,

    # Thư mục & Checkpoint
    'dataset_dir': '/content/drive/MyDrive/Photometric_DB_Full/',
    'checkpoint_1': '/content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_Shuffle/checkpoints/best_model.pth',
    'checkpoint_2': '/content/drive/MyDrive/Photometric_DB_Full/experiments/Single_NORMALMAP_Shuffle/checkpoints/best_model.pth',

    'device': device,
    'epochs': 119,
    'num_workers': 2,
    'batch_size': 16,
    'image_size': 112,
    'base_lr': 1e-4,
    'backbone': 'miresnet18',
    'num_classes': None,


    'loss_gender_weight': 1.0,      'loss_da_gender_weight': 0.1,
    'loss_emotion_weight': 0.5,     'loss_da_emotion_weight': 0.1,
    'loss_pose_weight': 1.0,        'loss_da_pose_weight': 0.1,
    'loss_spectacles_weight': 0.5,  'loss_da_spectacles_weight': 0.1,
    'loss_facial_hair_weight': 0.5, 'loss_da_facial_hair_weight': 0.1,
}

# --- 1. MANAGER ---
manager = ExperimentManager(CONFIGURATION)
manager.log_text(f"MODE: {EXPERIMENT_NAME} | Shuffle: {not CONFIGURATION['use_sampler']}")

# --- 2. DATASET ---
train_csv_path = os.path.join(CONFIGURATION['dataset_dir'], 'dataset/train_split.csv')
if not os.path.exists(train_csv_path): train_csv_path = os.path.join(CONFIGURATION['dataset_dir'], 'train_split.csv')
df_temp = pd.read_csv(train_csv_path)
CONFIGURATION['num_classes'] = df_temp['id'].max() + 1
manager.log_text(f"Num Classes: {CONFIGURATION['num_classes']}")

train_transform = A.Compose([
    RandomResizedCropRect(CONFIGURATION['image_size']),
    GaussianNoise(p=0.2),
], additional_targets={'image2': 'image'})

test_transform = A.Compose([
    A.Resize(height=CONFIGURATION['image_size'], width=CONFIGURATION['image_size'])
], additional_targets={'image2': 'image'})

# Load Data (Shuffle/Sampler tự động theo config)
train_dataloader, test_dataloader = create_concatv2_multitask_datafetcher(CONFIGURATION, train_transform, test_transform)

# --- 3. MODEL SETUP ---
# Load Backbone 1 (Albedo)
checkpoint_1 = torch.load(CONFIGURATION['checkpoint_1'], map_location=device, weights_only=False)

mtl_backbone1 = MTLFaceRecognition(CONFIGURATION['backbone'], CONFIGURATION['num_classes'])
# Fix lỗi key nếu có 'module.' prefix
state_dict_1 = {k.replace('module.', ''): v for k, v in checkpoint_1['model_state_dict'].items()}
mtl_backbone1.load_state_dict(state_dict_1, strict=False)

# Load Backbone 2 (Normal)
checkpoint_2 = torch.load(CONFIGURATION['checkpoint_2'], map_location=device, weights_only=False)

mtl_backbone2 = MTLFaceRecognition(CONFIGURATION['backbone'], CONFIGURATION['num_classes'])
state_dict_2 = {k.replace('module.', ''): v for k, v in checkpoint_2['model_state_dict'].items()}
mtl_backbone2.load_state_dict(state_dict_2, strict=False)

# Combine Model
model = ConcatMTLFaceRecognitionV2(mtl_backbone1, mtl_backbone2, CONFIGURATION['num_classes'])

# Freeze Backbones (Chỉ train phần đầu Concat)
for param in model.mtl_backbone1.parameters(): param.requires_grad = False
for param in model.mtl_backbone2.parameters(): param.requires_grad = False

criterion = ConcatMultiTaskLoss(train_csv_path, CONFIGURATION)
optimizer = Adam(model.parameters(), lr=CONFIGURATION['base_lr'])
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=40, T_mult=1, eta_min=1e-6)

# --- 4. CHECKPOINT & EARLY STOP ---
ckpt_saver = ModelCheckpoint(
    output_dir=manager.ckpt_dir,
    mode='max',
    best_metric_name='auc_id_cosine'
)

early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['cosine_auc'], patience=1000, mode='max', verbose=0,
    save_dir=manager.ckpt_dir, start_from_epoch=0
)

# --- 5. FIT ---
fit(
    conf=CONFIGURATION,
    start_epoch=0,
    model=model,
    train_dataloader=train_dataloader,
    test_dataloader=test_dataloader,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    early_stopping=early_stopping,
    model_checkpoint=ckpt_saver,
    existing_manager=manager
)
# Out:
# /content/FR_Photometric_Stereo
# KHOI TAO THI NGHIEM: Concat_ALBEDO_NORMAL_Shuffle
# Luu tru tai: /content/drive/MyDrive/Photometric_DB_Full/experiments/Concat_ALBEDO_NORMAL_Shuffle
# Thoi gian: 2026-01-10 10:32:53
# --------------------------------------------------
# MODE: Concat_ALBEDO_NORMAL_Shuffle | Shuffle: True
# Num Classes: 2232
# >>> ConcatV2Loader: MODE = RANDOM SHUFFLE
# BAT DAU CONCAT TRAINING: Concat_ALBEDO_NORMAL_Shuffle
#
# --- Epoch 1/119 ---
# Ep 1:
# ╒══════════════════╤════════════╤═════════════════════╕
# │ Metric           │      Train │ Test                │
# ╞══════════════════╪════════════╪═════════════════════╡
# │ loss             │ 26.3038    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_id          │ 26.0792    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_gender      │  0.0335484 │ 0.03544724898205863 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_emotion     │  0.134922  │ 0.17678268253803253 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_pose        │  0.0234823 │ 0.03469053552382522 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair │  0.0965627 │ 0.1710377393497361  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles  │  0.103682  │ 0.07396328076720238 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_gender       │  0.999976  │ 0.9677685099371846  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles   │  0.999524  │ 0.9780080213903743  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair  │  0.999779  │ 0.8215589684149522  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_pose         │  0.970502  │ 0.7953179867342957  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_emotion      │  0.961472  │ 0.7629255319148937  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine    │  1         │ 0.981145755127389   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean │  1         │ 0.9811458035396321  │
# ╘══════════════════╧════════════╧═════════════════════╛
# Ep 1: loss: 26.3038, loss_id: 26.0792, loss_gender: 0.0354, loss_emotion: 0.1768, loss_pose: 0.0347, loss_facial_hair: 0.1710, loss_spectacles: 0.0740, auc_gender: 0.9678, auc_spectacles: 0.9780, auc_facial_hair: 0.8216, auc_pose: 0.7953, auc_emotion: 0.7629, auc_id_cosine: 0.9811, auc_id_euclidean: 0.9811
# --> SAVE BEST MODEL (auc_id_cosine: 0.9811)
#
# --- Epoch 2/119 ---
# Ep 2:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 25.2489    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 25.1438    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │  0.0116827 │ 0.03274544395713343  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │  0.0812463 │ 0.17343023129635388  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │  0.0151585 │ 0.03574476670473814  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │  0.0386012 │ 0.18476066759063137  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │  0.0366824 │ 0.056231399377187095 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │  0.999991  │ 0.9706518381217175   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │  0.999605  │ 0.979879679144385    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │  0.999916  │ 0.829440741813967    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │  0.992188  │ 0.8227077643386655   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │  0.983223  │ 0.7798936170212767   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │  0.999999  │ 0.9808424040125616   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │  0.999999  │ 0.9808424040125616   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 2: loss: 25.2489, loss_id: 25.1438, loss_gender: 0.0327, loss_emotion: 0.1734, loss_pose: 0.0357, loss_facial_hair: 0.1848, loss_spectacles: 0.0562, auc_gender: 0.9707, auc_spectacles: 0.9799, auc_facial_hair: 0.8294, auc_pose: 0.8227, auc_emotion: 0.7799, auc_id_cosine: 0.9808, auc_id_euclidean: 0.9808
#
# --- Epoch 3/119 ---
# Ep 3:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 20.7641     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 20.6877     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │  0.00645076 │ 0.035553657178146146 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │  0.0666789  │ 0.18092146101925108  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │  0.0114025  │ 0.040030375252374344 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │  0.0267334  │ 0.19049656794716915  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │  0.0237219  │ 0.054060740965522    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │  1          │ 0.9686952939964988   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │  0.999749   │ 0.979144385026738    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │  0.999925   │ 0.8377861489423355   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │  0.997419   │ 0.8365977370269215   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │  0.990005   │ 0.7827659574468085   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │  1          │ 0.9803350437056048   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │  1          │ 0.9803350437056049   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 3: loss: 20.7641, loss_id: 20.6877, loss_gender: 0.0356, loss_emotion: 0.1809, loss_pose: 0.0400, loss_facial_hair: 0.1905, loss_spectacles: 0.0541, auc_gender: 0.9687, auc_spectacles: 0.9791, auc_facial_hair: 0.8378, auc_pose: 0.8366, auc_emotion: 0.7828, auc_id_cosine: 0.9803, auc_id_euclidean: 0.9803
#
# --- Epoch 4/119 ---
# Ep 4:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 16.4734     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 16.4122     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │  0.00474383 │ 0.037652383377361626 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │  0.0547548  │ 0.19171727531486088  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │  0.00965517 │ 0.04764221300784913  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │  0.0202325  │ 0.19506792610304224  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │  0.0184514  │ 0.05128050750742356  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │  0.999991   │ 0.972299454227165    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │  0.999831   │ 0.9792112299465241   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │  0.999904   │ 0.8396406838597509   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │  0.994763   │ 0.8372220054623488   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │  0.990632   │ 0.7812234042553191   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │  1          │ 0.9812575389965459   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │  1          │ 0.9812575632026674   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 4: loss: 16.4734, loss_id: 16.4122, loss_gender: 0.0377, loss_emotion: 0.1917, loss_pose: 0.0476, loss_facial_hair: 0.1951, loss_spectacles: 0.0513, auc_gender: 0.9723, auc_spectacles: 0.9792, auc_facial_hair: 0.8396, auc_pose: 0.8372, auc_emotion: 0.7812, auc_id_cosine: 0.9813, auc_id_euclidean: 0.9813
# --> SAVE BEST MODEL (auc_id_cosine: 0.9813)
#
# --- Epoch 5/119 ---
# Ep 5:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 13.3017     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 13.2471     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │  0.00310125 │ 0.04385346608210562  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │  0.0497149  │ 0.20735563544763458  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │  0.00859669 │ 0.053433666109210916 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │  0.0207222  │ 0.19620620500710276  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │  0.0154149  │ 0.04632085804930992  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │  0.999996   │ 0.9720935022139842   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │  0.999629   │ 0.979077540106952    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │  0.999871   │ 0.8401043175891046   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │  0.997568   │ 0.8479906359734686   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │  0.992284   │ 0.7757446808510639   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │  1          │ 0.9807757887661521   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │  1          │ 0.980775788766152    │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 5: loss: 13.3017, loss_id: 13.2471, loss_gender: 0.0439, loss_emotion: 0.2074, loss_pose: 0.0534, loss_facial_hair: 0.1962, loss_spectacles: 0.0463, auc_gender: 0.9721, auc_spectacles: 0.9791, auc_facial_hair: 0.8401, auc_pose: 0.8480, auc_emotion: 0.7757, auc_id_cosine: 0.9808, auc_id_euclidean: 0.9808
#
# --- Epoch 6/119 ---
# Ep 6:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 11.0001     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 10.9489     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │  0.00250876 │ 0.044111129970082805 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │  0.0506143  │ 0.199369751330879    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │  0.00759374 │ 0.054202353271345295 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │  0.0169186  │ 0.21391772758215666  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │  0.0146423  │ 0.05095250061195758  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │  1          │ 0.9705488621151271   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │  0.999893   │ 0.978475935828877    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │  0.999937   │ 0.8376122862938279   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │  0.998538   │ 0.8448692937963325   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │  0.992419   │ 0.7805319148936171   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │  1          │ 0.9800945800944736   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │  1          │ 0.9800945316822306   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 6: loss: 11.0001, loss_id: 10.9489, loss_gender: 0.0441, loss_emotion: 0.1994, loss_pose: 0.0542, loss_facial_hair: 0.2139, loss_spectacles: 0.0510, auc_gender: 0.9705, auc_spectacles: 0.9785, auc_facial_hair: 0.8376, auc_pose: 0.8449, auc_emotion: 0.7805, auc_id_cosine: 0.9801, auc_id_euclidean: 0.9801
#
# --- Epoch 7/119 ---
# Ep 7:
# ╒══════════════════╤════════════╤═════════════════════╕
# │ Metric           │      Train │ Test                │
# ╞══════════════════╪════════════╪═════════════════════╡
# │ loss             │ 9.38383    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_id          │ 9.33709    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_gender      │ 0.00258171 │ 0.04595406127110538 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0449429  │ 0.21066842186782095 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_pose        │ 0.00754451 │ 0.05565150433944331 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.0162578  │ 0.23158676751578847 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.0120382  │ 0.05106348875496122 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_gender       │ 1          │ 0.9713726701678507  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999791   │ 0.9794117647058824  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.99988    │ 0.8398725007244277  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_pose         │ 0.99886    │ 0.8487709715177526  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_emotion      │ 0.992489   │ 0.7794680851063829  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1          │ 0.98097737734613    │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1          │ 0.9809773531400083  │
# ╘══════════════════╧════════════╧═════════════════════╛
# Ep 7: loss: 9.3838, loss_id: 9.3371, loss_gender: 0.0460, loss_emotion: 0.2107, loss_pose: 0.0557, loss_facial_hair: 0.2316, loss_spectacles: 0.0511, auc_gender: 0.9714, auc_spectacles: 0.9794, auc_facial_hair: 0.8399, auc_pose: 0.8488, auc_emotion: 0.7795, auc_id_cosine: 0.9810, auc_id_euclidean: 0.9810
#
# --- Epoch 8/119 ---
# Ep 8:
# ╒══════════════════╤════════════╤═════════════════════╕
# │ Metric           │      Train │ Test                │
# ╞══════════════════╪════════════╪═════════════════════╡
# │ loss             │ 8.13395    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_id          │ 8.08917    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_gender      │ 0.00234786 │ 0.04164549956072329 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0446236  │ 0.20986159187224177 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_pose        │ 0.00726703 │ 0.0508019817320423  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.0136725  │ 0.24774231554733384 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.0120378  │ 0.04965992427120606 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_gender       │ 0.999993   │ 0.9743589743589743  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999867   │ 0.9793449197860963  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999951   │ 0.8418429440741814  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_pose         │ 0.998456   │ 0.8518142801404603  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_emotion      │ 0.992875   │ 0.7780851063829787  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1          │ 0.9806526280198831  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1          │ 0.9806526522260047  │
# ╘══════════════════╧════════════╧═════════════════════╛
# Ep 8: loss: 8.1340, loss_id: 8.0892, loss_gender: 0.0416, loss_emotion: 0.2099, loss_pose: 0.0508, loss_facial_hair: 0.2477, loss_spectacles: 0.0497, auc_gender: 0.9744, auc_spectacles: 0.9793, auc_facial_hair: 0.8418, auc_pose: 0.8518, auc_emotion: 0.7781, auc_id_cosine: 0.9807, auc_id_euclidean: 0.9807
#
# --- Epoch 9/119 ---
# Ep 9:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 7.20286    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 7.16185    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.00175081 │ 0.0433862206668386   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0429405  │ 0.2158183716237545   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00635196 │ 0.073586658303005    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.0125216  │ 0.27591585849101347  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.0103385  │ 0.048970195206089154 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.9728143342601173   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999765   │ 0.9785427807486631   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999627   │ 0.8378441031585048   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.998411   │ 0.8498634412797503   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.993652   │ 0.7756914893617022   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 1          │ 0.9810421529273043   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 1          │ 0.9810422013395473   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 9: loss: 7.2029, loss_id: 7.1619, loss_gender: 0.0434, loss_emotion: 0.2158, loss_pose: 0.0736, loss_facial_hair: 0.2759, loss_spectacles: 0.0490, auc_gender: 0.9728, auc_spectacles: 0.9785, auc_facial_hair: 0.8378, auc_pose: 0.8499, auc_emotion: 0.7757, auc_id_cosine: 0.9810, auc_id_euclidean: 0.9810
#
# --- Epoch 10/119 ---
# Ep 10:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 6.49394    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 6.45391    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.00174625 │ 0.03930780815749636  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0400275  │ 0.22861925057239002  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00669367 │ 0.06694699257301788  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.0113955  │ 0.23329264665436414  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.0117481  │ 0.050305100080246724 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.9746679023787458   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.99968    │ 0.9796122994652406   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999934   │ 0.8406838597507968   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.998018   │ 0.8496293406164651   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.99383    │ 0.7799468085106382   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999998   │ 0.9808727584889415   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999998   │ 0.9808727584889416   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 10: loss: 6.4939, loss_id: 6.4539, loss_gender: 0.0393, loss_emotion: 0.2286, loss_pose: 0.0669, loss_facial_hair: 0.2333, loss_spectacles: 0.0503, auc_gender: 0.9747, auc_spectacles: 0.9796, auc_facial_hair: 0.8407, auc_pose: 0.8496, auc_emotion: 0.7799, auc_id_cosine: 0.9809, auc_id_euclidean: 0.9809
#
# --- Epoch 11/119 ---
# Ep 11:
# ╒══════════════════╤════════════╤═════════════════════╕
# │ Metric           │      Train │ Test                │
# ╞══════════════════╪════════════╪═════════════════════╡
# │ loss             │ 5.93632    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_id          │ 5.89756    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_gender      │ 0.0023588  │ 0.03962500498811197 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0394639  │ 0.23387551762991482 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_pose        │ 0.00655673 │ 0.06953215952186535 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.0113725  │ 0.2868999171122495  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.00884704 │ 0.05159817870137178 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_gender       │ 1          │ 0.9749768303985171  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999853   │ 0.9786764705882353  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999933   │ 0.838655462184874   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_pose         │ 0.998317   │ 0.8482247366367538  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_emotion      │ 0.992361   │ 0.7770744680851064  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1          │ 0.9814603862948427  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1          │ 0.9814604347070854  │
# ╘══════════════════╧════════════╧═════════════════════╛
# Ep 11: loss: 5.9363, loss_id: 5.8976, loss_gender: 0.0396, loss_emotion: 0.2339, loss_pose: 0.0695, loss_facial_hair: 0.2869, loss_spectacles: 0.0516, auc_gender: 0.9750, auc_spectacles: 0.9787, auc_facial_hair: 0.8387, auc_pose: 0.8482, auc_emotion: 0.7771, auc_id_cosine: 0.9815, auc_id_euclidean: 0.9815
# --> SAVE BEST MODEL (auc_id_cosine: 0.9815)
#
# --- Epoch 12/119 ---
# Ep 12:
# ╒══════════════════╤════════════╤═════════════════════╕
# │ Metric           │      Train │ Test                │
# ╞══════════════════╪════════════╪═════════════════════╡
# │ loss             │ 5.53196    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_id          │ 5.49258    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_gender      │ 0.00122599 │ 0.04427269006393746 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0378803  │ 0.24792164978053835 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_pose        │ 0.00605642 │ 0.07049868396845543 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.0152827  │ 0.2648926256483214  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.0110252  │ 0.05114678374310541 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_gender       │ 1          │ 0.9744619503655648  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999924   │ 0.9787433155080215  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999748   │ 0.8421327151550275  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_pose         │ 0.997718   │ 0.8530628170113148  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_emotion      │ 0.994275   │ 0.7779255319148937  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1          │ 0.9803259906161581  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1          │ 0.9803259664100366  │
# ╘══════════════════╧════════════╧═════════════════════╛
# Ep 12: loss: 5.5320, loss_id: 5.4926, loss_gender: 0.0443, loss_emotion: 0.2479, loss_pose: 0.0705, loss_facial_hair: 0.2649, loss_spectacles: 0.0511, auc_gender: 0.9745, auc_spectacles: 0.9787, auc_facial_hair: 0.8421, auc_pose: 0.8531, auc_emotion: 0.7779, auc_id_cosine: 0.9803, auc_id_euclidean: 0.9803
#
# --- Epoch 13/119 ---
# Ep 13:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 5.17592    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 5.13719    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.00139418 │ 0.045006648451413236 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0403724  │ 0.2459360874361462   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00529713 │ 0.07605751501654999  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.0136714  │ 0.27779323848274845  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.010032   │ 0.05469232637874989  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.9741530223457935   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999923   │ 0.9796122994652406   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.99994    │ 0.8375543320776586   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.99791    │ 0.849629340616465    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.993578   │ 0.7754255319148937   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 1          │ 0.9817935593513767   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 1          │ 0.9817935109391336   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 13: loss: 5.1759, loss_id: 5.1372, loss_gender: 0.0450, loss_emotion: 0.2459, loss_pose: 0.0761, loss_facial_hair: 0.2778, loss_spectacles: 0.0547, auc_gender: 0.9742, auc_spectacles: 0.9796, auc_facial_hair: 0.8376, auc_pose: 0.8496, auc_emotion: 0.7754, auc_id_cosine: 0.9818, auc_id_euclidean: 0.9818
# --> SAVE BEST MODEL (auc_id_cosine: 0.9818)
#
# --- Epoch 14/119 ---
# Ep 14:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 4.95399    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 4.91505    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.00182531 │ 0.04698675689966573  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.039225   │ 0.26306332233879304  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00619684 │ 0.08211371359518832  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.0125856  │ 0.2606912334966991   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.0100149  │ 0.054219183634914875 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.9745649263721553   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999844   │ 0.9794786096256685   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999937   │ 0.84045204288612     │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.998981   │ 0.849629340616465    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.993939   │ 0.7796808510638297   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 1          │ 0.9809777162318308   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 1          │ 0.9809776920257096   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 14: loss: 4.9540, loss_id: 4.9151, loss_gender: 0.0470, loss_emotion: 0.2631, loss_pose: 0.0821, loss_facial_hair: 0.2607, loss_spectacles: 0.0542, auc_gender: 0.9746, auc_spectacles: 0.9795, auc_facial_hair: 0.8405, auc_pose: 0.8496, auc_emotion: 0.7797, auc_id_cosine: 0.9810, auc_id_euclidean: 0.9810
#
# --- Epoch 15/119 ---
# Ep 15:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 4.65249    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 4.61508    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.00137724 │ 0.0464543846367936   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0379811  │ 0.2404862493276596   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00557805 │ 0.07611555533690585  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.0112699  │ 0.2813320301938802   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.0116514  │ 0.054196231241803616 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.9751827824116981   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999912   │ 0.9794117647058824   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.99993    │ 0.8397565922920893   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.997806   │ 0.8537651190011706   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.992337   │ 0.7806382978723403   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 1          │ 0.9806344734287469   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 1          │ 0.9806344734287468   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 15: loss: 4.6525, loss_id: 4.6151, loss_gender: 0.0465, loss_emotion: 0.2405, loss_pose: 0.0761, loss_facial_hair: 0.2813, loss_spectacles: 0.0542, auc_gender: 0.9752, auc_spectacles: 0.9794, auc_facial_hair: 0.8398, auc_pose: 0.8538, auc_emotion: 0.7806, auc_id_cosine: 0.9806, auc_id_euclidean: 0.9806
#
# --- Epoch 16/119 ---
# Ep 16:
# ╒══════════════════╤═════════════╤═════════════════════╕
# │ Metric           │       Train │ Test                │
# ╞══════════════════╪═════════════╪═════════════════════╡
# │ loss             │ 4.38721     │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_id          │ 4.3525      │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_gender      │ 0.000985534 │ 0.03773121205934634 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0368252   │ 0.25646451405353016 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_pose        │ 0.00512897  │ 0.08027609295418693 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.0103027   │ 0.28646503262118334 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.0100568   │ 0.05558220328788997 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_gender       │ 0.999994    │ 0.975182782411698   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999919    │ 0.9785427807486631  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999958    │ 0.8421906693711968  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_pose         │ 0.998316    │ 0.8489270386266095  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_emotion      │ 0.99377     │ 0.7781914893617021  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1           │ 0.9803456459868284  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1           │ 0.9803456459868283  │
# ╘══════════════════╧═════════════╧═════════════════════╛
# Ep 16: loss: 4.3872, loss_id: 4.3525, loss_gender: 0.0377, loss_emotion: 0.2565, loss_pose: 0.0803, loss_facial_hair: 0.2865, loss_spectacles: 0.0556, auc_gender: 0.9752, auc_spectacles: 0.9785, auc_facial_hair: 0.8422, auc_pose: 0.8489, auc_emotion: 0.7782, auc_id_cosine: 0.9803, auc_id_euclidean: 0.9803
#
# --- Epoch 17/119 ---
# Ep 17:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 4.19029     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 4.15443     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │ 0.000858202 │ 0.040356699294837504 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0363584   │ 0.26931066314379376  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │ 0.00573346  │ 0.06960564142920905  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.0128764   │ 0.2935276166277213   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00929892  │ 0.052741057291213006 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │ 1           │ 0.9744619503655648   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999925    │ 0.9781417112299465   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999972    │ 0.8423065778035352   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │ 0.998264    │ 0.855013655872025    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │ 0.993926    │ 0.7756382978723404   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │ 1           │ 0.9808550154018711   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │ 1           │ 0.9808550396079925   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 17: loss: 4.1903, loss_id: 4.1544, loss_gender: 0.0404, loss_emotion: 0.2693, loss_pose: 0.0696, loss_facial_hair: 0.2935, loss_spectacles: 0.0527, auc_gender: 0.9745, auc_spectacles: 0.9781, auc_facial_hair: 0.8423, auc_pose: 0.8550, auc_emotion: 0.7756, auc_id_cosine: 0.9809, auc_id_euclidean: 0.9809
#
# --- Epoch 18/119 ---
# Ep 18:
# ╒══════════════════╤═════════════╤═════════════════════╕
# │ Metric           │       Train │ Test                │
# ╞══════════════════╪═════════════╪═════════════════════╡
# │ loss             │ 4.03152     │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_id          │ 3.998       │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_gender      │ 0.000706511 │ 0.04522790485579106 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0362509   │ 0.2629026451872455  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_pose        │ 0.00529584  │ 0.08157454257727498 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.0100309   │ 0.2741244870962368  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.00874333  │ 0.05281692352339936 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_gender       │ 1           │ 0.9731232622798888  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999936    │ 0.9790775401069518  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999898    │ 0.8395827296435816  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_pose         │ 0.999369    │ 0.8553257900897386  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_emotion      │ 0.993636    │ 0.7749468085106384  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1           │ 0.9808187304257199  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1           │ 0.9808187062195983  │
# ╘══════════════════╧═════════════╧═════════════════════╛
# Ep 18: loss: 4.0315, loss_id: 3.9980, loss_gender: 0.0452, loss_emotion: 0.2629, loss_pose: 0.0816, loss_facial_hair: 0.2741, loss_spectacles: 0.0528, auc_gender: 0.9731, auc_spectacles: 0.9791, auc_facial_hair: 0.8396, auc_pose: 0.8553, auc_emotion: 0.7749, auc_id_cosine: 0.9808, auc_id_euclidean: 0.9808
#
# --- Epoch 19/119 ---
# Ep 19:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 3.96621     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 3.92712     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │ 0.000995437 │ 0.049199241203799225 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0372251   │ 0.2525392236808936   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │ 0.00533966  │ 0.08536916259779698  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.015589    │ 0.24853543730245697  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.0126898   │ 0.06036954366006992  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │ 1           │ 0.9756976624446503   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999796    │ 0.9800802139037433   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999917    │ 0.8405099971022892   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │ 0.998497    │ 0.8569644947327351   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │ 0.993377    │ 0.7766489361702128   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │ 1           │ 0.981851750867499    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │ 1           │ 0.9818517508674989   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 19: loss: 3.9662, loss_id: 3.9271, loss_gender: 0.0492, loss_emotion: 0.2525, loss_pose: 0.0854, loss_facial_hair: 0.2485, loss_spectacles: 0.0604, auc_gender: 0.9757, auc_spectacles: 0.9801, auc_facial_hair: 0.8405, auc_pose: 0.8570, auc_emotion: 0.7766, auc_id_cosine: 0.9819, auc_id_euclidean: 0.9819
# --> SAVE BEST MODEL (auc_id_cosine: 0.9819)
#
# --- Epoch 20/119 ---
# Ep 20:
# ╒══════════════════╤════════════╤═════════════════════╕
# │ Metric           │      Train │ Test                │
# ╞══════════════════╪════════════╪═════════════════════╡
# │ loss             │ 3.74181    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_id          │ 3.70531    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_gender      │ 0.00072397 │ 0.05217729827563744 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0411557  │ 0.25607023139794666 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_pose        │ 0.00571546 │ 0.07816492922655824 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.0107169  │ 0.2791752047940261  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.00824877 │ 0.05962991409857447 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_gender       │ 1          │ 0.9739470703326125  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999934   │ 0.9801470588235295  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999958   │ 0.8438133874239351  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_pose         │ 0.998499   │ 0.8551697229808817  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_emotion      │ 0.994571   │ 0.7805319148936168  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1          │ 0.981211402128938   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1          │ 0.9812114021289381  │
# ╘══════════════════╧════════════╧═════════════════════╛
# Ep 20: loss: 3.7418, loss_id: 3.7053, loss_gender: 0.0522, loss_emotion: 0.2561, loss_pose: 0.0782, loss_facial_hair: 0.2792, loss_spectacles: 0.0596, auc_gender: 0.9739, auc_spectacles: 0.9801, auc_facial_hair: 0.8438, auc_pose: 0.8552, auc_emotion: 0.7805, auc_id_cosine: 0.9812, auc_id_euclidean: 0.9812
#
# --- Epoch 21/119 ---
# Ep 21:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 3.62806     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 3.59336     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │ 0.000805917 │ 0.04962193398063795  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0392216   │ 0.2768528440760242   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │ 0.00531467  │ 0.08423786941501829  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.0110027   │ 0.29971630265936255  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00692218  │ 0.059313196882915996 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │ 1           │ 0.9759036144578314   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999843    │ 0.9796791443850267   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999924    │ 0.8428861199652274   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │ 0.998622    │ 0.8525946156847445   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │ 0.993408    │ 0.7751063829787234   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │ 1           │ 0.9814184612923783   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │ 1           │ 0.9814184612923784   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 21: loss: 3.6281, loss_id: 3.5934, loss_gender: 0.0496, loss_emotion: 0.2769, loss_pose: 0.0842, loss_facial_hair: 0.2997, loss_spectacles: 0.0593, auc_gender: 0.9759, auc_spectacles: 0.9797, auc_facial_hair: 0.8429, auc_pose: 0.8526, auc_emotion: 0.7751, auc_id_cosine: 0.9814, auc_id_euclidean: 0.9814
#
# --- Epoch 22/119 ---
# Ep 22:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 3.4983      │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 3.46275     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │ 0.000846953 │ 0.05622015394086096  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0358565   │ 0.27116183357106316  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │ 0.00562073  │ 0.08672942394494182  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.0143511   │ 0.31073429634691113  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00795904  │ 0.054336961122721225 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │ 1           │ 0.9739470703326124   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999683    │ 0.9794117647058823   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999983    │ 0.8458997392060272   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │ 0.998735    │ 0.8539992196644558   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │ 0.992272    │ 0.778404255319149    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │ 1           │ 0.9813974019666603   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │ 1           │ 0.9813974261727818   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 22: loss: 3.4983, loss_id: 3.4627, loss_gender: 0.0562, loss_emotion: 0.2712, loss_pose: 0.0867, loss_facial_hair: 0.3107, loss_spectacles: 0.0543, auc_gender: 0.9739, auc_spectacles: 0.9794, auc_facial_hair: 0.8459, auc_pose: 0.8540, auc_emotion: 0.7784, auc_id_cosine: 0.9814, auc_id_euclidean: 0.9814
#
# --- Epoch 23/119 ---
# Ep 23:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 3.35787    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 3.3232     │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.0014979  │ 0.04889375465346449  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0374327  │ 0.2518087464074294   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00521334 │ 0.08995418374737103  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.0106311  │ 0.2877393125090748   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00785248 │ 0.055752884179431327 │
# ├──────────────────┼────────────┼──────────────────────┤
# ...
# │ loss_spectacles  │ 0.00607668  │ 0.06323667524945147 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_gender       │ 1           │ 0.9772423025435074  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999911    │ 0.9801470588235295  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999964    │ 0.8425383946682121  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_pose         │ 0.998453    │ 0.8535310183378852  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_emotion      │ 0.991866    │ 0.7735106382978724  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1           │ 0.9803865543321889  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1           │ 0.9803865301260675  │
# ╘══════════════════╧═════════════╧═════════════════════╛
# Ep 112: loss: 1.1405, loss_id: 1.1130, loss_gender: 0.0590, loss_emotion: 0.3613, loss_pose: 0.1050, loss_facial_hair: 0.3638, loss_spectacles: 0.0632, auc_gender: 0.9772, auc_spectacles: 0.9801, auc_facial_hair: 0.8425, auc_pose: 0.8535, auc_emotion: 0.7735, auc_id_cosine: 0.9804, auc_id_euclidean: 0.9804
#
# --- Epoch 113/119 ---
# Ep 113:
# ╒══════════════════╤═════════════╤═════════════════════╕
# │ Metric           │       Train │ Test                │
# ╞══════════════════╪═════════════╪═════════════════════╡
# │ loss             │ 1.14316     │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_id          │ 1.10911     │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_gender      │ 0.000426241 │ 0.06615042145050312 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0353758   │ 0.33548383394049275 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_pose        │ 0.00541045  │ 0.1311711555527937  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.0113009   │ 0.31832004004778963 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.0097385   │ 0.06591342844250095 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_gender       │ 1           │ 0.9766244465039645  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999968    │ 0.9802807486631017  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999999    │ 0.846884960880904   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_pose         │ 0.998801    │ 0.8577448302770191  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_emotion      │ 0.99216     │ 0.7710638297872341  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1           │ 0.9810242403973832  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1           │ 0.9810242888096263  │
# ╘══════════════════╧═════════════╧═════════════════════╛
# Ep 113: loss: 1.1432, loss_id: 1.1091, loss_gender: 0.0662, loss_emotion: 0.3355, loss_pose: 0.1312, loss_facial_hair: 0.3183, loss_spectacles: 0.0659, auc_gender: 0.9766, auc_spectacles: 0.9803, auc_facial_hair: 0.8469, auc_pose: 0.8577, auc_emotion: 0.7711, auc_id_cosine: 0.9810, auc_id_euclidean: 0.9810
#
# --- Epoch 114/119 ---
# Ep 114:
# ╒══════════════════╤═════════════╤═════════════════════╕
# │ Metric           │       Train │ Test                │
# ╞══════════════════╪═════════════╪═════════════════════╡
# │ loss             │ 1.11799     │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_id          │ 1.08984     │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_gender      │ 0.000181502 │ 0.06129428415624716 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0318484   │ 0.3400057835711373  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_pose        │ 0.0043444   │ 0.1313171420673219  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.00942049  │ 0.33588816622634315 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.00596737  │ 0.06283164348537361 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_gender       │ 1           │ 0.9778601585830502  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999891    │ 0.9796791443850269  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999967    │ 0.8464213271515504  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_pose         │ 0.99855     │ 0.8576667967225907  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_emotion      │ 0.991539    │ 0.7697340425531914  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1           │ 0.9817640762953711  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1           │ 0.9817640762953712  │
# ╘══════════════════╧═════════════╧═════════════════════╛
# Ep 114: loss: 1.1180, loss_id: 1.0898, loss_gender: 0.0613, loss_emotion: 0.3400, loss_pose: 0.1313, loss_facial_hair: 0.3359, loss_spectacles: 0.0628, auc_gender: 0.9779, auc_spectacles: 0.9797, auc_facial_hair: 0.8464, auc_pose: 0.8577, auc_emotion: 0.7697, auc_id_cosine: 0.9818, auc_id_euclidean: 0.9818
#
# --- Epoch 115/119 ---
# Ep 115:
# ╒══════════════════╤═════════════╤═════════════════════╕
# │ Metric           │       Train │ Test                │
# ╞══════════════════╪═════════════╪═════════════════════╡
# │ loss             │ 1.15386     │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_id          │ 1.12651     │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_gender      │ 0.000341047 │ 0.06127389096016284 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0324114   │ 0.3622899125847552  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_pose        │ 0.00402296  │ 0.12940092291682959 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.00700007  │ 0.36967630116527694 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.0065634   │ 0.06335908425131088 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_gender       │ 1           │ 0.9772423025435073  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999933    │ 0.9799465240641713  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999989    │ 0.8440452042886118  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_pose         │ 0.998966    │ 0.8564962934061646  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_emotion      │ 0.99289     │ 0.7685106382978724  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1           │ 0.9806133656907856  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1           │ 0.9806133172785424  │
# ╘══════════════════╧═════════════╧═════════════════════╛
# Ep 115: loss: 1.1539, loss_id: 1.1265, loss_gender: 0.0613, loss_emotion: 0.3623, loss_pose: 0.1294, loss_facial_hair: 0.3697, loss_spectacles: 0.0634, auc_gender: 0.9772, auc_spectacles: 0.9799, auc_facial_hair: 0.8440, auc_pose: 0.8565, auc_emotion: 0.7685, auc_id_cosine: 0.9806, auc_id_euclidean: 0.9806
#
# --- Epoch 116/119 ---
# Ep 116:
# ╒══════════════════╤═════════════╤═════════════════════╕
# │ Metric           │       Train │ Test                │
# ╞══════════════════╪═════════════╪═════════════════════╡
# │ loss             │ 1.13967     │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_id          │ 1.10793     │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_gender      │ 0.000217745 │ 0.04845822917903004 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0355234   │ 0.3227983553790384  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_pose        │ 0.00451259  │ 0.12149072876976182 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.0103473   │ 0.37017943360842764 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.00815878  │ 0.0632871663547121  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_gender       │ 1           │ 0.9764184944907837  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999859    │ 0.9796122994652408  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999995    │ 0.8473485946102579  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_pose         │ 0.998895    │ 0.8555598907530239  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_emotion      │ 0.991103    │ 0.769840425531915   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1           │ 0.980644446350811   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1           │ 0.980644446350811   │
# ╘══════════════════╧═════════════╧═════════════════════╛
# Ep 116: loss: 1.1397, loss_id: 1.1079, loss_gender: 0.0485, loss_emotion: 0.3228, loss_pose: 0.1215, loss_facial_hair: 0.3702, loss_spectacles: 0.0633, auc_gender: 0.9764, auc_spectacles: 0.9796, auc_facial_hair: 0.8473, auc_pose: 0.8556, auc_emotion: 0.7698, auc_id_cosine: 0.9806, auc_id_euclidean: 0.9806
#
# --- Epoch 117/119 ---
# Ep 117:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 1.12982    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 1.1019     │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.00015246 │ 0.060887256247547664 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0302579  │ 0.3532396890223026   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00486518 │ 0.10946104084400253  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.00988626 │ 0.29427066789422596  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00565019 │ 0.06229054029002631  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.9768303985171455   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999981   │ 0.9796791443850267   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999984   │ 0.8505360764995654   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.999366   │ 0.8542333203277409   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.992841   │ 0.7693085106382979   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 1          │ 0.9811083808757698   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 1          │ 0.9811083808757697   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 117: loss: 1.1298, loss_id: 1.1019, loss_gender: 0.0609, loss_emotion: 0.3532, loss_pose: 0.1095, loss_facial_hair: 0.2943, loss_spectacles: 0.0623, auc_gender: 0.9768, auc_spectacles: 0.9797, auc_facial_hair: 0.8505, auc_pose: 0.8542, auc_emotion: 0.7693, auc_id_cosine: 0.9811, auc_id_euclidean: 0.9811
#
# --- Epoch 118/119 ---
# Ep 118:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 1.1923      │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 1.16255     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │ 0.000217029 │ 0.055382425469563006 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0338835   │ 0.3373206626209948   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │ 0.00472114  │ 0.12617142339392254  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.00819086  │ 0.37682939651939606  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00755054  │ 0.06274483188624597  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │ 0.999996    │ 0.9771393265369169   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999946    │ 0.9796122994652406   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999994    │ 0.8431758910460736   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │ 0.998936    │ 0.8563402262973079   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │ 0.991541    │ 0.7688829787234042   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │ 1           │ 0.9812196806224963   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │ 1           │ 0.9812197290347392   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 118: loss: 1.1923, loss_id: 1.1625, loss_gender: 0.0554, loss_emotion: 0.3373, loss_pose: 0.1262, loss_facial_hair: 0.3768, loss_spectacles: 0.0627, auc_gender: 0.9771, auc_spectacles: 0.9796, auc_facial_hair: 0.8432, auc_pose: 0.8563, auc_emotion: 0.7689, auc_id_cosine: 0.9812, auc_id_euclidean: 0.9812
#
# --- Epoch 119/119 ---
# Ep 119:
# ╒══════════════════╤════════════╤═════════════════════╕
# │ Metric           │      Train │ Test                │
# ╞══════════════════╪════════════╪═════════════════════╡
# │ loss             │ 1.15326    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_id          │ 1.12463    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_gender      │ 0.00024779 │ 0.06208329647213557 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0329365  │ 0.33590830200248295 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_pose        │ 0.00332709 │ 0.12877214517599592 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.0103919  │ 0.3552184724636997  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.0067917  │ 0.05988404110151654 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_gender       │ 1          │ 0.9760065904644217  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999982   │ 0.9799465240641712  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.99997    │ 0.8437554332077659  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_pose         │ 0.998533   │ 0.85868123293016    │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_emotion      │ 0.993212   │ 0.7687765957446808  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine    │ 1          │ 0.9817161965870144  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean │ 1          │ 0.9817161965870143  │
# ╘══════════════════╧════════════╧═════════════════════╛
# Ep 119: loss: 1.1533, loss_id: 1.1246, loss_gender: 0.0621, loss_emotion: 0.3359, loss_pose: 0.1288, loss_facial_hair: 0.3552, loss_spectacles: 0.0599, auc_gender: 0.9760, auc_spectacles: 0.9799, auc_facial_hair: 0.8438, auc_pose: 0.8587, auc_emotion: 0.7688, auc_id_cosine: 0.9817, auc_id_euclidean: 0.9817
# CONCAT TRAINING HOAN TAT.
