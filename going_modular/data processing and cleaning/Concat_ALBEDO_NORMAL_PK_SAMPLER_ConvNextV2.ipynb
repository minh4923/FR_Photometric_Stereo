# %%
from google.colab import drive
import os

# 1. Mount Drive
drive.mount('/content/drive')

# 2. Clone NHÁNH convnext-v2-dev
if not os.path.exists('/content/FR_Photometric_Stereo'):
    # !git clone -b convnext-v2-dev https://github.com/minh4923/FR_Photometric_Stereo.git

# 3. Di chuyển vào thư mục dự án
# %cd /content/FR_Photometric_Stereo

# 4. Cài đặt thư viện
# !pip install -q albumentations==1.3.1 timm
# Out:
# Mounted at /content/drive
# Cloning into 'FR_Photometric_Stereo'...
# remote: Enumerating objects: 157, done.
# remote: Counting objects: 100% (157/157), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 157 (delta 55), reused 146 (delta 44), pack-reused 0 (from 0)
# Receiving objects: 100% (157/157), 10.80 MiB | 15.96 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/FR_Photometric_Stereo
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.7/125.7 kB 13.0 MB/s eta 0:00:00

# %%
# %cd /content/FR_Photometric_Stereo
import warnings
warnings.filterwarnings("ignore")
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
import albumentations as A
import os
import torch
import pandas as pd

from going_modular.dataloader.multitask import create_concatv2_multitask_datafetcher
from going_modular.model.MTLFaceRecognition import MTLFaceRecognition
from going_modular.model.ConcatMTLFaceRecognition import ConcatMTLFaceRecognitionV2
from going_modular.loss.ConcatMultiTaskLoss import ConcatMultiTaskLoss
from going_modular.train_eval.concat_train import fit
from going_modular.utils.transforms import RandomResizedCropRect, GaussianNoise
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint
from going_modular.utils.ExperimentManager import ExperimentManager

device = "cuda" if torch.cuda.is_available() else "cpu"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Đặt seed toàn cục
seed = 42
torch.manual_seed(seed)

# --- TÊN THÍ NGHIỆM ---
EXPERIMENT_NAME = "Concat_ALBEDO_NORMAL_PK_SAMPLER_ConvNextV2"

CONFIGURATION = {
    'note': EXPERIMENT_NAME,
    'type': 'concat_v2',


    'use_sampler': True,

    # Thư mục
    'dataset_dir': '/content/drive/MyDrive/Photometric_DB_Full/',


    'checkpoint_1': '/content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth',


    'checkpoint_2': '/content/drive/MyDrive/Photometric_DB_Full/experiments/Single_NORMALMAP_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth',

    'device': device,
    'epochs': 119,
    'num_workers': 2,
    'batch_size': 16,
    'image_size': 112,
    'base_lr': 1e-4,

    # --- QUAN TRỌNG: ĐỔI BACKBONE ---
    'backbone': 'convnextv2_tiny',
    'num_classes': None,


    'loss_gender_weight': 1.0,      'loss_da_gender_weight': 0.1,
    'loss_emotion_weight': 0.5,     'loss_da_emotion_weight': 0.1,
    'loss_pose_weight': 1.0,        'loss_da_pose_weight': 0.1,
    'loss_spectacles_weight': 0.5,  'loss_da_spectacles_weight': 0.1,
    'loss_facial_hair_weight': 0.5, 'loss_da_facial_hair_weight': 0.1,
}


manager = ExperimentManager(CONFIGURATION)
manager.log_text(f"MODE: {EXPERIMENT_NAME} | Backbone: {CONFIGURATION['backbone']} | Sampler: {CONFIGURATION['use_sampler']}")

# --- 2. DATASET ---
train_csv_path = os.path.join(CONFIGURATION['dataset_dir'], 'dataset/train_split.csv')
if not os.path.exists(train_csv_path): train_csv_path = os.path.join(CONFIGURATION['dataset_dir'], 'train_split.csv')
df_temp = pd.read_csv(train_csv_path)
CONFIGURATION['num_classes'] = df_temp['id'].max() + 1
manager.log_text(f"Num Classes: {CONFIGURATION['num_classes']}")

train_transform = A.Compose([
    RandomResizedCropRect(CONFIGURATION['image_size']),
    GaussianNoise(p=0.2),
], additional_targets={'image2': 'image'})

test_transform = A.Compose([
    A.Resize(height=CONFIGURATION['image_size'], width=CONFIGURATION['image_size'])
], additional_targets={'image2': 'image'})

# Load Data
train_dataloader, test_dataloader = create_concatv2_multitask_datafetcher(CONFIGURATION, train_transform, test_transform)

# --- 3. MODEL SETUP ---
# Load Backbone 1 (Albedo)
print(f"Loading Checkpoint 1: {CONFIGURATION['checkpoint_1']}")
checkpoint_1 = torch.load(CONFIGURATION['checkpoint_1'], map_location=device, weights_only=False)

mtl_backbone1 = MTLFaceRecognition(CONFIGURATION['backbone'], CONFIGURATION['num_classes'])
state_dict_1 = {k.replace('module.', ''): v for k, v in checkpoint_1['model_state_dict'].items()}
mtl_backbone1.load_state_dict(state_dict_1, strict=False)

# Load Backbone 2 (Normal)
print(f"Loading Checkpoint 2: {CONFIGURATION['checkpoint_2']}")
checkpoint_2 = torch.load(CONFIGURATION['checkpoint_2'], map_location=device, weights_only=False)

mtl_backbone2 = MTLFaceRecognition(CONFIGURATION['backbone'], CONFIGURATION['num_classes'])
state_dict_2 = {k.replace('module.', ''): v for k, v in checkpoint_2['model_state_dict'].items()}
mtl_backbone2.load_state_dict(state_dict_2, strict=False)

# Combine Model
model = ConcatMTLFaceRecognitionV2(mtl_backbone1, mtl_backbone2, CONFIGURATION['num_classes'])

# Freeze Backbones
for param in model.mtl_backbone1.parameters(): param.requires_grad = False
for param in model.mtl_backbone2.parameters(): param.requires_grad = False

criterion = ConcatMultiTaskLoss(train_csv_path, CONFIGURATION)
optimizer = Adam(model.parameters(), lr=CONFIGURATION['base_lr'])
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=40, T_mult=1, eta_min=1e-6)

# --- 4. CHECKPOINT & EARLY STOP ---
ckpt_saver = ModelCheckpoint(
    output_dir=manager.ckpt_dir,
    mode='max',
    best_metric_name='auc_id_cosine'
)

early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['cosine_auc'], patience=1000, mode='max', verbose=0,
    save_dir=manager.ckpt_dir, start_from_epoch=0
)

# --- 5. FIT ---
fit(
    conf=CONFIGURATION,
    start_epoch=0,
    model=model,
    train_dataloader=train_dataloader,
    test_dataloader=test_dataloader,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    early_stopping=early_stopping,
    model_checkpoint=ckpt_saver,
    existing_manager=manager
)
# Out:
# /content/FR_Photometric_Stereo
# KHOI TAO THI NGHIEM: Concat_ALBEDO_NORMAL_PK_SAMPLER_ConvNextV2
# Luu tru tai: /content/drive/MyDrive/Photometric_DB_Full/experiments/Concat_ALBEDO_NORMAL_PK_SAMPLER_ConvNextV2
# Thoi gian: 2026-01-11 14:33:05
# --------------------------------------------------
# MODE: Concat_ALBEDO_NORMAL_PK_SAMPLER_ConvNextV2 | Backbone: convnextv2_tiny | Sampler: True
# Num Classes: 2232
# >>> ConcatV2Loader: MODE = PK SAMPLER
# Loading Checkpoint 1: /content/drive/MyDrive/Photometric_DB_Full/experiments/Single_ALBEDO_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth
# --- Loading ConvNeXt V2: convnextv2_tiny (Pretrained=True) ---
# Loading Checkpoint 2: /content/drive/MyDrive/Photometric_DB_Full/experiments/Single_NORMALMAP_PK_SAMPLER_ConvNextV2/checkpoints/best_model.pth
# --- Loading ConvNeXt V2: convnextv2_tiny (Pretrained=True) ---
# BAT DAU CONCAT TRAINING: Concat_ALBEDO_NORMAL_PK_SAMPLER_ConvNextV2
#
# --- Epoch 1/119 ---
# Ep 1:
# ╒══════════════════╤════════════╤═════════════════════╕
# │ Metric           │      Train │ Test                │
# ╞══════════════════╪════════════╪═════════════════════╡
# │ loss             │ 31.1943    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_id          │ 30.9512    │ -                   │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_gender      │  0.0496443 │ 0.03322572747452392 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_emotion     │  0.111071  │ 0.14810937518874803 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_pose        │  0.0246766 │ 0.03604652846439017 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair │  0.121723  │ 0.1573647248248259  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles  │  0.104873  │ 0.06350944915579425 │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_gender       │  0.997936  │ 0.9828030068993924  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles   │  0.999971  │ 0.9792112299465241  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair  │  0.998741  │ 0.8457838307736889  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_pose         │  0.973387  │ 0.7087787748731954  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_emotion      │  0.99367   │ 0.8348936170212766  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine    │  0.999889  │ 0.9808617204975307  │
# ├──────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean │  0.999889  │ 0.9808617204975307  │
# ╘══════════════════╧════════════╧═════════════════════╛
# Ep 1: loss: 31.1943, loss_id: 30.9512, loss_gender: 0.0332, loss_emotion: 0.1481, loss_pose: 0.0360, loss_facial_hair: 0.1574, loss_spectacles: 0.0635, auc_gender: 0.9828, auc_spectacles: 0.9792, auc_facial_hair: 0.8458, auc_pose: 0.7088, auc_emotion: 0.8349, auc_id_cosine: 0.9809, auc_id_euclidean: 0.9809
# --> SAVE BEST MODEL (auc_id_cosine: 0.9809)
#
# --- Epoch 2/119 ---
# Ep 2:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 34.0143    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 33.9032    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │  0.0223969 │ 0.02387892475558652  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │  0.0593887 │ 0.15510187132491005  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │  0.0138454 │ 0.036244369888057314 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │  0.0510509 │ 0.1593768284138706   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │  0.0392648 │ 0.04396245975254311  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │  1         │ 0.9878488312223253   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │  0.999826  │ 0.9767379679144386   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │  0.999084  │ 0.8609098811938569   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │  0.989431  │ 0.7490440889582521   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │  0.993873  │ 0.8427659574468085   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │  0.999997  │ 0.9804769399899265   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │  0.999997  │ 0.9804769399899262   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 2: loss: 34.0143, loss_id: 33.9032, loss_gender: 0.0239, loss_emotion: 0.1551, loss_pose: 0.0362, loss_facial_hair: 0.1594, loss_spectacles: 0.0440, auc_gender: 0.9878, auc_spectacles: 0.9767, auc_facial_hair: 0.8609, auc_pose: 0.7490, auc_emotion: 0.8428, auc_id_cosine: 0.9805, auc_id_euclidean: 0.9805
#
# --- Epoch 3/119 ---
# Ep 3:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 30.7818    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 30.7079    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │  0.013427  │ 0.018787033648954496 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │  0.0437662 │ 0.15618697885009977  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │  0.0106999 │ 0.03914140552903215  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │  0.0313218 │ 0.17253918987181452  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │  0.0242772 │ 0.041026876437374286 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │  1         │ 0.9892904953145917   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │  0.999623  │ 0.9760695187165775   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │  0.999585  │ 0.8625325992465952   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │  0.992378  │ 0.7725321888412017   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │  0.996964  │ 0.8437234042553191   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │  0.999998  │ 0.981243451033824    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │  0.999998  │ 0.9812434510338242   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 3: loss: 30.7818, loss_id: 30.7079, loss_gender: 0.0188, loss_emotion: 0.1562, loss_pose: 0.0391, loss_facial_hair: 0.1725, loss_spectacles: 0.0410, auc_gender: 0.9893, auc_spectacles: 0.9761, auc_facial_hair: 0.8625, auc_pose: 0.7725, auc_emotion: 0.8437, auc_id_cosine: 0.9812, auc_id_euclidean: 0.9812
# --> SAVE BEST MODEL (auc_id_cosine: 0.9812)
#
# --- Epoch 4/119 ---
# Ep 4:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 27.2624     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 27.2042     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │  0.00986177 │ 0.016506163468067016 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │  0.0377879  │ 0.1673605398585399   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │  0.00903639 │ 0.04711713776406315  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │  0.0234481  │ 0.1848563603642914   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │  0.0173342  │ 0.04117342353694969  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │  1          │ 0.989805375347544    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │  0.999915   │ 0.9752673796791445   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │  0.999373   │ 0.8628803245436105   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │  0.992319   │ 0.776824034334764    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │  0.997788   │ 0.8447340425531914   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │  0.999962   │ 0.9807664452032472   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │  0.999962   │ 0.9807664452032472   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 4: loss: 27.2624, loss_id: 27.2042, loss_gender: 0.0165, loss_emotion: 0.1674, loss_pose: 0.0471, loss_facial_hair: 0.1849, loss_spectacles: 0.0412, auc_gender: 0.9898, auc_spectacles: 0.9753, auc_facial_hair: 0.8629, auc_pose: 0.7768, auc_emotion: 0.8447, auc_id_cosine: 0.9808, auc_id_euclidean: 0.9808
#
# --- Epoch 5/119 ---
# Ep 5:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │
│
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │  0.999987   │ 0.9809964517698838   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │  0.999987   │ 0.9809964759760054   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 8: loss: 12.9953, loss_id: 12.9610, loss_gender: 0.0147, loss_emotion: 0.2035, loss_pose: 0.0641, loss_facial_hair: 0.2226, loss_spectacles: 0.0424, auc_gender: 0.9912, auc_spectacles: 0.9751, auc_facial_hair: 0.8676, auc_pose: 0.7906, auc_emotion: 0.8486, auc_id_cosine: 0.9810, auc_id_euclidean: 0.9810
#
# --- Epoch 9/119 ---
# Ep 9:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 9.64441    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 9.61276    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.00293029 │ 0.015146111380696917 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0246396  │ 0.19168238672945234  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00651112 │ 0.06769391283806828  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.0118547  │ 0.2045590023820599   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00790967 │ 0.0430254025462394   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.9916589434661723   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999971   │ 0.9750668449197862   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999746   │ 0.8671689365401334   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.997277   │ 0.7879047990635973   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.999031   │ 0.85                 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999999   │ 0.9797842092044068   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999999   │ 0.9797841849982853   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 9: loss: 9.6444, loss_id: 9.6128, loss_gender: 0.0151, loss_emotion: 0.1917, loss_pose: 0.0677, loss_facial_hair: 0.2046, loss_spectacles: 0.0430, auc_gender: 0.9917, auc_spectacles: 0.9751, auc_facial_hair: 0.8672, auc_pose: 0.7879, auc_emotion: 0.8500, auc_id_cosine: 0.9798, auc_id_euclidean: 0.9798
#
# --- Epoch 10/119 ---
# Ep 10:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 6.86965    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 6.83914    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.0024275  │ 0.01446081260089866  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0241066  │ 0.2003826385156976   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00661215 │ 0.057644271136571966 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.0107085  │ 0.22326124679400688  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00811833 │ 0.043350468169794314 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.991350015446401    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999997   │ 0.9745320855614974   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999866   │ 0.8687337003767025   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.997151   │ 0.7908700741318767   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.998163   │ 0.8499999999999999   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999932   │ 0.9803571196884265   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999932   │ 0.9803571196884266   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 10: loss: 6.8696, loss_id: 6.8391, loss_gender: 0.0145, loss_emotion: 0.2004, loss_pose: 0.0576, loss_facial_hair: 0.2233, loss_spectacles: 0.0434, auc_gender: 0.9914, auc_spectacles: 0.9745, auc_facial_hair: 0.8687, auc_pose: 0.7909, auc_emotion: 0.8500, auc_id_cosine: 0.9804, auc_id_euclidean: 0.9804
#
# --- Epoch 11/119 ---
# Ep 11:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 4.67258    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 4.64157    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.0027081  │ 0.014965765288151387 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0281966  │ 0.19735335869093737  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00642909 │ 0.07286512911216253  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.0110656  │ 0.2478966920170933   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00448405 │ 0.045142425990585856 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.9918648954793533   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999992   │ 0.9746657754010696   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999798   │ 0.8659518980005796   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.994771   │ 0.7921186110027311   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.998922   │ 0.8487765957446808   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999998   │ 0.9805127166375258   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999998   │ 0.9805127166375258   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 11: loss: 4.6726, loss_id: 4.6416, loss_gender: 0.0150, loss_emotion: 0.1974, loss_pose: 0.0729, loss_facial_hair: 0.2479, loss_spectacles: 0.0451, auc_gender: 0.9919, auc_spectacles: 0.9747, auc_facial_hair: 0.8660, auc_pose: 0.7921, auc_emotion: 0.8488, auc_id_cosine: 0.9805, auc_id_euclidean: 0.9805
#
# --- Epoch 12/119 ---
# Ep 12:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 3.20361    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 3.17488    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.
│
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 19: loss: 1.4622, loss_id: 1.4370, loss_gender: 0.0158, loss_emotion: 0.2136, loss_pose: 0.0701, loss_facial_hair: 0.2558, loss_spectacles: 0.0500, auc_gender: 0.9930, auc_spectacles: 0.9745, auc_facial_hair: 0.8644, auc_pose: 0.7954, auc_emotion: 0.8496, auc_id_cosine: 0.9809, auc_id_euclidean: 0.9809
#
# --- Epoch 20/119 ---
# Ep 20:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 1.38976    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 1.36805    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.00149406 │ 0.014972531627992995 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0174546  │ 0.22394671787818274  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00502931 │ 0.08319892325542039  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.00825734 │ 0.244543285212583    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00465459 │ 0.05158685472431696  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.9932035835650294   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999847   │ 0.9744652406417114   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999898   │ 0.8685018835120255   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.998323   │ 0.7916504096761607   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.999286   │ 0.848031914893617    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999997   │ 0.9805310648776341   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999997   │ 0.9805310406715126   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 20: loss: 1.3898, loss_id: 1.3681, loss_gender: 0.0150, loss_emotion: 0.2239, loss_pose: 0.0832, loss_facial_hair: 0.2445, loss_spectacles: 0.0516, auc_gender: 0.9932, auc_spectacles: 0.9745, auc_facial_hair: 0.8685, auc_pose: 0.7917, auc_emotion: 0.8480, auc_id_cosine: 0.9805, auc_id_euclidean: 0.9805
#
# --- Epoch 21/119 ---
# Ep 21:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 1.3975     │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 1.37749    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.00109659 │ 0.020720206332043745 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0181898  │ 0.2237637084391382   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00451158 │ 0.0795083465313332   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.00742892 │ 0.25840230187815094  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.0031972  │ 0.05005056111743519  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.9924827515188961   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 1          │ 0.9744652406417114   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999913   │ 0.8634019124891337   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.997957   │ 0.7973468591494343   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.99897    │ 0.8491489361702127   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999994   │ 0.9806480288567953   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999994   │ 0.9806481014751598   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 21: loss: 1.3975, loss_id: 1.3775, loss_gender: 0.0207, loss_emotion: 0.2238, loss_pose: 0.0795, loss_facial_hair: 0.2584, loss_spectacles: 0.0501, auc_gender: 0.9925, auc_spectacles: 0.9745, auc_facial_hair: 0.8634, auc_pose: 0.7973, auc_emotion: 0.8491, auc_id_cosine: 0.9806, auc_id_euclidean: 0.9806
#
# --- Epoch 22/119 ---
# Ep 22:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 1.35067    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 1.32881    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.00111176 │ 0.018161944956874423 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0197455  │ 0.236502416845825    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00532654 │ 0.0840687645573376   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.00697048 │ 0.27097798307012355  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00411732 │ 0.051930796288717024 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.9918648954793533   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 1          │ 0.9743983957219252   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999793   │ 0.8634019124891336   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.998569   │ 0.7932110807647288   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.999021   │ 0.8497872340425532   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999987   │ 0.9807474191917364   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999987   │ 0.9807474191917364   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 22: loss: 1.3507, loss_id: 1.3288, loss_gender: 0.0182, loss_emotion: 0.2365, loss_pose: 0.0841, loss_facial_hair: 0.2710, loss_spectacles: 0.0519, auc_gender: 0.9919, auc_spectacles: 0.9744, auc_facial_hair: 0.8634, auc_pose: 0.7932, auc_emotion: 0.8498, auc_id_cosine: 0.9807, auc_id_euclidean: 0.9807
#
# --- Epoch 23/119 ---
# Ep 23:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 1.29673    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 1.27774    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.00101681 │ 0.01733400216067417  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0175615  │ 0.21750216455095345  │
# ...
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_spectacles   │ 0.999985    │ 0.9739973262032087  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999964    │ 0.8625905534627644  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_pose         │ 0.998653    │ 0.7964104564962934  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_emotion      │ 0.999224    │ 0.8475531914893617  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_cosine    │ 0.999993    │ 0.980309578865771   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_euclidean │ 0.999993    │ 0.9803095788657709  │
# ╘══════════════════╧═════════════╧═════════════════════╛
# Ep 112: loss: 1.1299, loss_id: 1.1145, loss_gender: 0.0185, loss_emotion: 0.2635, loss_pose: 0.1110, loss_facial_hair: 0.3074, loss_spectacles: 0.0668, auc_gender: 0.9932, auc_spectacles: 0.9740, auc_facial_hair: 0.8626, auc_pose: 0.7964, auc_emotion: 0.8476, auc_id_cosine: 0.9803, auc_id_euclidean: 0.9803
#
# --- Epoch 113/119 ---
# Ep 113:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 1.14709     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 1.13        │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │ 0.000494924 │ 0.015903103739118605 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0190798   │ 0.25243943246702355  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │ 0.0034575   │ 0.09265685619579421  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.00389214  │ 0.319276496147116    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00329529  │ 0.0672186208980242   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │ 1           │ 0.9939244156111626   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999998    │ 0.9737967914438503   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999982    │ 0.8620689655172413   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │ 0.998937    │ 0.7913382754584471   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │ 0.999074    │ 0.8471808510638298   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999995    │ 0.9799857009598986   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999995    │ 0.9799857009598985   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 113: loss: 1.1471, loss_id: 1.1300, loss_gender: 0.0159, loss_emotion: 0.2524, loss_pose: 0.0927, loss_facial_hair: 0.3193, loss_spectacles: 0.0672, auc_gender: 0.9939, auc_spectacles: 0.9738, auc_facial_hair: 0.8621, auc_pose: 0.7913, auc_emotion: 0.8472, auc_id_cosine: 0.9800, auc_id_euclidean: 0.9800
#
# --- Epoch 114/119 ---
# Ep 114:
# ╒══════════════════╤═════════════╤═════════════════════╕
# │ Metric           │       Train │ Test                │
# ╞══════════════════╪═════════════╪═════════════════════╡
# │ loss             │ 1.11503     │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_id          │ 1.09823     │ -                   │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_gender      │ 0.000226893 │ 0.01823999111921795 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_emotion     │ 0.0184955   │ 0.26123747188184    │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_pose        │ 0.00355723  │ 0.09233634732663631 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_facial_hair │ 0.00501806  │ 0.3249251105492779  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ loss_spectacles  │ 0.00252618  │ 0.06589065471740065 │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_gender       │ 1           │ 0.9933065595716198  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_spectacles   │ 1           │ 0.9739304812834225  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_facial_hair  │ 0.999954    │ 0.8613155607070414  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_pose         │ 0.998565    │ 0.7954740538431525  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_emotion      │ 0.999674    │ 0.8475531914893617  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_cosine    │ 0.999996    │ 0.9801688928875248  │
# ├──────────────────┼─────────────┼─────────────────────┤
# │ auc_id_euclidean │ 0.999996    │ 0.9801689170936466  │
# ╘══════════════════╧═════════════╧═════════════════════╛
# Ep 114: loss: 1.1150, loss_id: 1.0982, loss_gender: 0.0182, loss_emotion: 0.2612, loss_pose: 0.0923, loss_facial_hair: 0.3249, loss_spectacles: 0.0659, auc_gender: 0.9933, auc_spectacles: 0.9739, auc_facial_hair: 0.8613, auc_pose: 0.7955, auc_emotion: 0.8476, auc_id_cosine: 0.9802, auc_id_euclidean: 0.9802
#
# --- Epoch 115/119 ---
# Ep 115:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 1.14537     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 1.13161     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │ 0.000157095 │ 0.022522330753316864 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0146195   │ 0.27699304682513076  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │ 0.00369818  │ 0.0940362346979479   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.00344139  │ 0.323622356983833    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00175305  │ 0.06724509209258638  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │ 1           │ 0.9929976315518484   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999994    │ 0.9738636363636364   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999947    │ 0.8616053317878877   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │ 0.998855    │ 0.7983612953570034   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │ 0.998973    │ 0.8479255319148936   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999995    │ 0.9797486746180226   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999995    │ 0.9797486746180226   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 115: loss: 1.1454, loss_id: 1.1316, loss_gender: 0.0225, loss_emotion: 0.2770, loss_pose: 0.0940, loss_facial_hair: 0.3236, loss_spectacles: 0.0672, auc_gender: 0.9930, auc_spectacles: 0.9739, auc_facial_hair: 0.8616, auc_pose: 0.7984, auc_emotion: 0.8479, auc_id_cosine: 0.9797, auc_id_euclidean: 0.9797
#
# --- Epoch 116/119 ---
# Ep 116:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 1.12742     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 1.11098     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │ 0.000178368 │ 0.022576333451777626 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │ 0.018023    │ 0.2679473718421327   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │ 0.00336336  │ 0.11412671356487812  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.00457372  │ 0.30026473456139985  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00319937  │ 0.06528415969983649  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │ 1           │ 0.9929976315518484   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999999    │ 0.9737967914438503   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999876    │ 0.8628223703274412   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │ 0.999293    │ 0.7937573156457277   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │ 0.999491    │ 0.8470212765957447   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999995    │ 0.9814363738222995   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999995    │ 0.9814363738222996   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 116: loss: 1.1274, loss_id: 1.1110, loss_gender: 0.0226, loss_emotion: 0.2679, loss_pose: 0.1141, loss_facial_hair: 0.3003, loss_spectacles: 0.0653, auc_gender: 0.9930, auc_spectacles: 0.9738, auc_facial_hair: 0.8628, auc_pose: 0.7938, auc_emotion: 0.8470, auc_id_cosine: 0.9814, auc_id_euclidean: 0.9814
#
# --- Epoch 117/119 ---
# Ep 117:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 1.12175     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 1.10658     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │ 0.000462709 │ 0.017846564583325945 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0156745   │ 0.2891295308040248   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │ 0.00394196  │ 0.09337373804818425  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.00250609  │ 0.3287111917096708   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00334164  │ 0.06667990284000148  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │ 1           │ 0.9932035835650292   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999749    │ 0.9738636363636364   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999981    │ 0.8616053317878877   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │ 0.998961    │ 0.7975029262582911   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │ 0.999309    │ 0.8473404255319148   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999937    │ 0.980373773500029    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999937    │ 0.9803737977061505   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 117: loss: 1.1218, loss_id: 1.1066, loss_gender: 0.0178, loss_emotion: 0.2891, loss_pose: 0.0934, loss_facial_hair: 0.3287, loss_spectacles: 0.0667, auc_gender: 0.9932, auc_spectacles: 0.9739, auc_facial_hair: 0.8616, auc_pose: 0.7975, auc_emotion: 0.8473, auc_id_cosine: 0.9804, auc_id_euclidean: 0.9804
#
# --- Epoch 118/119 ---
# Ep 118:
# ╒══════════════════╤════════════╤══════════════════════╕
# │ Metric           │      Train │ Test                 │
# ╞══════════════════╪════════════╪══════════════════════╡
# │ loss             │ 1.13811    │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_id          │ 1.1194     │ -                    │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_gender      │ 0.0043952  │ 0.019233066044560272 │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0156205  │ 0.26511319540441036  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_pose        │ 0.00271694 │ 0.1145732109176202   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.00572901 │ 0.3393788403126463   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00185097 │ 0.06763287669713867  │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_gender       │ 1          │ 0.9932035835650294   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999926   │ 0.9739973262032087   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999852   │ 0.8621269197334105   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_pose         │ 0.999077   │ 0.7982832618025751   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_emotion      │ 0.999399   │ 0.8477659574468085   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999954   │ 0.9802700502693367   │
# ├──────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999954   │ 0.9802700986815798   │
# ╘══════════════════╧════════════╧══════════════════════╛
# Ep 118: loss: 1.1381, loss_id: 1.1194, loss_gender: 0.0192, loss_emotion: 0.2651, loss_pose: 0.1146, loss_facial_hair: 0.3394, loss_spectacles: 0.0676, auc_gender: 0.9932, auc_spectacles: 0.9740, auc_facial_hair: 0.8621, auc_pose: 0.7983, auc_emotion: 0.8478, auc_id_cosine: 0.9803, auc_id_euclidean: 0.9803
#
# --- Epoch 119/119 ---
# Ep 119:
# ╒══════════════════╤═════════════╤══════════════════════╕
# │ Metric           │       Train │ Test                 │
# ╞══════════════════╪═════════════╪══════════════════════╡
# │ loss             │ 1.14891     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_id          │ 1.13315     │ -                    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_gender      │ 0.000166672 │ 0.015094095501909679 │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_emotion     │ 0.0162062   │ 0.25463094127674896  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_pose        │ 0.00452326  │ 0.09325532210318165  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_facial_hair │ 0.00394089  │ 0.3220493294744908   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ loss_spectacles  │ 0.00198646  │ 0.06802687776992873  │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_gender       │ 1           │ 0.9933065595716198   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_spectacles   │ 0.999998    │ 0.9737967914438503   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_facial_hair  │ 0.999871    │ 0.8639235004346567   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_pose         │ 0.999175    │ 0.7942255169722982   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_emotion      │ 0.998032    │ 0.847287234042553    │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_cosine    │ 0.999998    │ 0.9808493753755578   │
# ├──────────────────┼─────────────┼──────────────────────┤
# │ auc_id_euclidean │ 0.999998    │ 0.9808493511694365   │
# ╘══════════════════╧═════════════╧══════════════════════╛
# Ep 119: loss: 1.1489, loss_id: 1.1332, loss_gender: 0.0151, loss_emotion: 0.2546, loss_pose: 0.0933, loss_facial_hair: 0.3220, loss_spectacles: 0.0680, auc_gender: 0.9933, auc_spectacles: 0.9738, auc_facial_hair: 0.8639, auc_pose: 0.7942, auc_emotion: 0.8473, auc_id_cosine: 0.9808, auc_id_euclidean: 0.9808
# CONCAT TRAINING HOAN TAT.
